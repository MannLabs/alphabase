# %%
INPUT_TABLE = "/Users/constantin/workspace/alphabase/test_data/unit_tests/input_table_formats/spectronaut.frgions.large.tsv"
INPUT_TABLE_MDIA = "/Users/constantin/workspace/alphabase/test_data/unit_tests/input_table_formats/diann_test_input_mDIA.tsv"

# %%
import alphabase.quantification.quant_reader.quant_reader_manager as quant_reader_manager

quant_reader_manager.import_data(INPUT_TABLE)
# Out:
# using input type spectronaut_fragion_isotopes
#      protein                                                ion  \
# 0     A5Z2X5  SEQ_LTGNPELSSLDEVLAK_MOD__LTGNPELSSLDEVLAK__CH...
# 1     A5Z2X5  SEQ_LTGNPELSSLDEVLAK_MOD__LTGNPELSSLDEVLAK__CH...
# 2     A5Z2X5  SEQ_LTGNPELSSLDEVLAK_MOD__LTGNPELSSLDEVLAK__CH...
# 3     A5Z2X5  SEQ_LTGNPELSSLDEVLAK_MOD__LTGNPELSSLDEVLAK__CH...
# 4     A5Z2X5  SEQ_LTGNPELSSLDEVLAK_MOD__LTGNPELSSLDEVLAK__CH...
# ...      ...                                                ...
# 8028  P00958  SEQ_YVMDDFEGQTSDK_MOD__YVM[Oxidation (M)]DDFEG...
# 8029  P00958  SEQ_YVMDDFEGQTSDK_MOD__YVM[Oxidation (M)]DDFEG...
# 8030  P00958  SEQ_YVMDDFEGQTSDK_MOD__YVM[Oxidation (M)]DDFEG...
# 8031  P00958  SEQ_YVMDDFEGQTSDK_MOD__YVM[Oxidation (M)]DDFEG...
# 8032  P00958  SEQ_YVMDDFEGQTSDK_MOD__YVM[Oxidation (M)]DDFEG...
#
#       20210603_EXPL1_MCT_SA_species_100ng_100_1_01.raw  \
# 0                                                  0.0
# ...
