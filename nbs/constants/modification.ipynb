# %%
#default_exp constants.modification

# %%
# hide
__file__ = '../../alphabase/constants/modification.py'

# %%
#export

# %%
#export
import os
import numba
import numpy as np
import pandas as pd
from typing import Union
from copy import deepcopy

from alphabase.yaml_utils import load_yaml
from alphabase.constants.element import calc_formula_mass

_base_dir = os.path.dirname(__file__)

def load_mod_yaml(yaml_file):
    global MOD_INFO_DICT
    global MOD_CHEM
    global MOD_MASS
    global MOD_LOSS_MASS
    global MOD_DF
    MOD_INFO_DICT = load_yaml(yaml_file)
    
    # Add lower-case modifications for future usages
    for key, modinfo in list(MOD_INFO_DICT.items()):
       modname, site = key.split('@')
       if len(site) == 1:
           MOD_INFO_DICT[modname+'@'+site.lower()] = deepcopy(modinfo)
           MOD_INFO_DICT[modname+'@'+site.lower()]['classification'] = 'Lower-case'

    MOD_CHEM = {}
    for key, val in MOD_INFO_DICT.items():
        MOD_CHEM[key] = val['composition']
        MOD_INFO_DICT[key]['unimod_mass'] = MOD_INFO_DICT[key]['mono_mass']
        MOD_INFO_DICT[key]['unimod_modloss'] = MOD_INFO_DICT[key]['modloss']
    

    MOD_MASS = dict(
        [
            (mod, calc_formula_mass(chem))
            for mod, chem in MOD_CHEM.items()
        ]
    )

    MOD_LOSS_MASS = dict(
        [
        (mod, calc_formula_mass(val['modloss_composition']))
        for mod, val in MOD_INFO_DICT.items()
        ]
    )

    MOD_DF = pd.DataFrame().from_dict(MOD_INFO_DICT, orient='index')
    MOD_DF['mass'] = pd.DataFrame().from_dict(MOD_MASS, orient='index')
    MOD_DF['modloss'] = pd.DataFrame().from_dict(MOD_LOSS_MASS, orient='index')

load_mod_yaml(
    os.path.join(_base_dir,
    'used_mod.yaml')
)

def load_modloss_importance(yaml_file):
    global MOD_LOSS_IMPORTANCE
    MOD_LOSS_IMPORTANCE = load_yaml(yaml_file)
    MOD_DF['modloss_importance'] = pd.DataFrame().from_dict(MOD_LOSS_IMPORTANCE, orient='index')
    MOD_DF.loc[pd.isna(MOD_DF['modloss_importance']), 'modloss_importance'] = 0


load_modloss_importance(
    os.path.join(_base_dir,
    'modloss_importance.yaml')
)

# %%
MOD_DF
# Out:
#                                    avge_mass       classification  \
# GlyGly@K                          114.042927   Post-translational
# 15N-oxobutanoic@C^Any N-term      -18.023900             Artefact
# 15N-oxobutanoic@S^Protein N-term  -18.023900   Post-translational
# 15N-oxobutanoic@T^Protein N-term  -18.023900   Post-translational
# 2-dimethylsuccinyl@C              144.125300  Chemical derivative
# ...                                      ...                  ...
# spermidine@q                      128.215300           Lower-case
# spermine@q                        185.309700           Lower-case
# sulfo+amino@y                      95.077800           Lower-case
# thioacylPA@k                      159.206200           Lower-case
# trifluoro@l                        53.971400           Lower-case
#
#                                            composition     modloss  \
# GlyGly@K                              H(6)C(4)N(2)O(2)  114.042922
# 15N-oxobutanoic@C^Any N-term              H(-3)15N(-1)    0.000000
# 15N-oxobutanoic@S^Protein N-term          H(-3)15N(-1)    0.000000
# 15N-oxobutanoic@T^Protein N-term          H(-3)15N(-1)    0.000000
# 2-dimethylsuccinyl@C                      H(8)C(6)O(4)    0.000000
# ...                                                ...         ...
# spermidine@q                             H(16)C(7)N(2)    0.000000
# spermine@q                              H(23)C(10)N(3)    0.000000
# sulfo+amino@y                         H(1)N(1)O(3)S(1)    0.000000
# thioacylPA@k                      H(9)C(6)N(1)O(2)S(1)    0.000000
# trifluoro@l                                  H(-3)F(3)    0.000000
#
#                                  modloss_composition   mono_mass  unimod_id  \
# GlyGly@K                            H(6)C(4)N(2)O(2)  114.042927         -1
# 15N-oxobutanoic@C^Any N-term                          -18.023584       1419
# 15N-oxobutanoic@S^Protein N-term                      -18.023584       1419
# 15N-oxobutanoic@T^Protein N-term                      -18.023584       1419
# 2-dimethylsuccinyl@C                                  144.042259       1262
# ...                                              ...         ...        ...
# spermidine@q                                          128.131349       1421
# spermine@q                                            185.189198       1420
# sulfo+amino@y                                          94.967714        997
# thioacylPA@k                                          159.035399        967
# trifluoro@l                                            53.971735        750
#
#                                   unimod_mass  unimod_modloss        mass  \
# GlyGly@K                           114.042927      114.042927  114.042922
# 15N-oxobutanoic@C^Any N-term       -18.023584        0.000000  -18.023583
# 15N-oxobutanoic@S^Protein N-term   -18.023584        0.000000  -18.023583
# 15N-oxobutanoic@T^Protein N-term   -18.023584        0.000000  -18.023583
# 2-dimethylsuccinyl@C               144.042259        0.000000  144.042253
# ...                                       ...             ...         ...
# spermidine@q                       128.131349        0.000000  128.131340
# spermine@q                         185.189198        0.000000  185.189185
# sulfo+amino@y                       94.967714        0.000000   94.967710
# thioacylPA@k                       159.035399        0.000000  159.035393
# trifluoro@l                         53.971735        0.000000   53.971736
#
#                                  modloss_importance
# GlyGly@K                                        1e6
# 15N-oxobutanoic@C^Any N-term                      0
# 15N-oxobutanoic@S^Protein N-term                  0
# 15N-oxobutanoic@T^Protein N-term                  0
# 2-dimethylsuccinyl@C                              0
# ...                                             ...
# spermidine@q                                      0
# spermine@q                                        0
# sulfo+amino@y                                     0
# thioacylPA@k                                      0
# trifluoro@l                                       0
#
# [5065 rows x 11 columns]

# %%
for mod, val in MOD_INFO_DICT.items():
    if abs(val['unimod_mass']-MOD_MASS[mod]) > 1e-5:
        print(f"{mod}: unimod mod={val['unimod_mass']}, formula mass={MOD_MASS[mod]}")
# Out:
# 4AcAllylGal@C: unimod mod=372.142033, formula mass=372.1420173
# ADP-Ribosyl@C: unimod mod=541.06111, formula mass=541.0610899000001
# ADP-Ribosyl@D: unimod mod=541.06111, formula mass=541.0610899000001
# ADP-Ribosyl@E: unimod mod=541.06111, formula mass=541.0610899000001
# ADP-Ribosyl@K: unimod mod=541.06111, formula mass=541.0610899000001
# ADP-Ribosyl@N: unimod mod=541.06111, formula mass=541.0610899000001
# ADP-Ribosyl@R: unimod mod=541.06111, formula mass=541.0610899000001
# ADP-Ribosyl@S: unimod mod=541.06111, formula mass=541.0610899000001
# ADP-Ribosyl@T: unimod mod=541.06111, formula mass=541.0610899000001
# AHA-Alkyne-KDDDD@M: unimod mod=695.280074, formula mass=695.2800427999999
# AHA-SS_CAM@M: unimod mod=252.097088, formula mass=252.09707669999997
# AMTzHexNAc2@N: unimod mod=502.202341, formula mass=502.2023182
# AMTzHexNAc2@S: unimod mod=502.202341, formula mass=502.2023182
# AMTzHexNAc2@T: unimod mod=502.202341, formula mass=502.2023182
# AROD@C: unimod mod=820.336015, formula mass=820.3359780999999
# Ahx2+Hsl@Any C-term: unimod mod=309.205242, formula mass=309.2052261
# Andro-H2O@C: unimod mod=332.19876, formula mass=332.1987452
# Archaeol@C: unimod mod=634.662782, formula mass=634.6627438
# Atto495Maleimide@C: unimod mod=474.250515, formula mass=474.25049549999994
# BADGE@C: unimod mod=340.167459, formula mass=340.1674468
# BHTOH@C: unimod mod=234.16198, formula mass=234.1619694
# BHTOH@H: unimod mod=234.16198, formula mass=234.1619694
# BHTOH@K: unimod mod=234.16198, formula mass=234.1619694
# Bacillosamine@N: unimod mod=228.111007, formula mass=228.1109964
# Biotin-HPDP@C: unimod mod=428.191582, formula mass=428.1915623
# Biotin-PEG-PRA@M: unimod mod=578.317646, formula mass=578.3176175000001
# Biotin-PEO-Amine@D: unimod mod=356.188212, formula mass=356.1881939
# Biotin-PEO-Amine@E: unimod mod=356.188212, formula mass=356.1881939
# Biotin-PEO-Amine@Protein C-term: unimod mod=356.188212, formula mass=356.1881939
# Biotin-phenacyl@C: unimod mod=626.263502, formula mass=626.263475
# Biotin-phenacyl@H: unimod mod=626.263502, formula mass=626.263475
# Biotin-phenacyl@S: unimod mod=626.263502, formula mass=626.263475
# Biotin-tyramide@Y: unimod mod=361.146012, formula mass=361.14599769999995
# Biotin:Cayman-10013@C: unimod mod=660.428442, formula mass=660.4284093
# Biotin:Cayman-10141@C: unimod mod=626.386577, formula mass=626.3865476
# Biotin:Invitrogen-M1602@C: unimod mod=523.210069, formula mass=523.2100465
# Biotin:Sigma-B1267@C: unimod mod=449.17329, formula mass=449.17327070000005
# Biotin:Thermo-21325@K: unimod mod=695.310118, formula mass=695.3100881
# Biotin:Thermo-21328@Any N-term: unimod mod=389.090154, formula mass=389.09013769999996
# Biotin:Thermo-21328@K: unimod mod=389.090154, formula mass=389.09013769999996
# Biotin:Thermo-21330@Any N-term: unimod mod=473.219571, formula mass=473.2195493
# Biotin:Thermo-21330@K: unimod mod=473.219571, formula mass=473.2195493
# Biotin:Thermo-21345@Q: unimod mod=311.166748, formula mass=311.1667328
# Biotin:Thermo-21360@Anywhere: unimod mod=487.246455, formula mass=487.2464307999999
# Biotin:Thermo-21901+2H2O@C: unimod mod=561.246849, formula mass=561.2468223
# Biotin:Thermo-21901+H2O@C: unimod mod=543.236284, formula mass=543.236259
# Biotin:Thermo-21911@C: unimod mod=921.461652, formula mass=921.4616082
# Biotin:Thermo-33033-H@Anywhere: unimod mod=546.208295, formula mass=546.208272
# Biotin:Thermo-33033@Anywhere: unimod mod=548.223945, formula mass=548.2239212
# Biotin:Thermo-88317@S: unimod mod=443.291294, formula mass=443.29127120000004
# Biotin:Thermo-88317@Y: unimod mod=443.291294, formula mass=443.29127120000004
# BisANS@K: unimod mod=594.091928, formula mass=594.0919121999999
# Bodipy@C: unimod mod=414.167478, formula mass=414.1674631
# Brij35@Any N-term: unimod mod=168.187801, formula mass=168.18779039999998
# Brij58@Any N-term: unimod mod=224.250401, formula mass=224.2503872
# C8-QAT@Any N-term: unimod mod=227.224915, formula mass=227.22490069999998
# C8-QAT@K: unimod mod=227.224915, formula mass=227.22490069999998
# CHDH@D: unimod mod=294.183109, formula mass=294.183096
# CIGG@K: unimod mod=330.136176, formula mass=330.1361604
# CLIP_TRAQ_3@Any N-term: unimod mod=271.148736, formula mass=271.1487234
# CLIP_TRAQ_3@K: unimod mod=271.148736, formula mass=271.1487234
# CLIP_TRAQ_3@Y: unimod mod=271.148736, formula mass=271.1487234
# CLIP_TRAQ_4@Any N-term: unimod mod=244.101452, formula mass=244.1014413
# CLIP_TRAQ_4@K: unimod mod=244.101452, formula mass=244.1014413
# CLIP_TRAQ_4@Y: unimod mod=244.101452, formula mass=244.1014413
# Can-FP-biotin@S: unimod mod=447.195679, formula mass=447.19565850000004
# Can-FP-biotin@T: unimod mod=447.195679, formula mass=447.19565850000004
# Can-FP-biotin@Y: unimod mod=447.195679, formula mass=447.19565850000004
# Cation:Cu[I]@Any C-term: unimod mod=61.921774, formula mass=61.9317734
# Cation:Cu[I]@D: unimod mod=61.921774, formula mass=61.9317734
# Cation:Cu[I]@E: unimod mod=61.921774, formula mass=61.9317734
# Cation:Cu[I]@H: unimod mod=61.921774, formula mass=61.9317734
# Cholesterol@Protein C-term: unimod mod=368.344302, formula mass=368.3442824
# CoenzymeA@C: unimod mod=765.09956, formula mass=765.0995304
# CuSMo@C: unimod mod=922.834855, formula mass=922.8448255000001
# Cy3-maleimide@C: unimod mod=753.262796, formula mass=753.2627666999999
# Cy3b-maleimide@C: unimod mod=682.24612, formula mass=682.2460963000001
# CyDye-Cy3@C: unimod mod=672.298156, formula mass=672.2981298
# CyDye-Cy5@C: unimod mod=684.298156, formula mass=684.2981298
# Cytopiloyne+water@Any N-term: unimod mod=380.147118, formula mass=380.1471032
# Cytopiloyne+water@C: unimod mod=380.147118, formula mass=380.1471032
# Cytopiloyne+water@K: unimod mod=380.147118, formula mass=380.1471032
# Cytopiloyne+water@R: unimod mod=380.147118, formula mass=380.1471032
# Cytopiloyne+water@S: unimod mod=380.147118, formula mass=380.1471032
# Cytopiloyne+water@T: unimod mod=380.147118, formula mass=380.1471032
# Cytopiloyne+water@Y: unimod mod=380.147118, formula mass=380.1471032
# Cytopiloyne@Any N-term: unimod mod=362.136553, formula mass=362.1365399
# Cytopiloyne@C: unimod mod=362.136553, formula mass=362.1365399
# Cytopiloyne@K: unimod mod=362.136553, formula mass=362.1365399
# Cytopiloyne@P: unimod mod=362.136553, formula mass=362.1365399
# Cytopiloyne@R: unimod mod=362.136553, formula mass=362.1365399
# Cytopiloyne@S: unimod mod=362.136553, formula mass=362.1365399
# Cytopiloyne@Y: unimod mod=362.136553, formula mass=362.1365399
# DEDGFLYMVYASQETFG@K: unimod mod=1970.824411, formula mass=1970.8243259000003
# Dap-DSP@A: unimod mod=364.076278, formula mass=364.07626300000004
# Dap-DSP@E: unimod mod=364.076278, formula mass=364.07626300000004
# Dap-DSP@K: unimod mod=364.076278, formula mass=364.07626300000004
# Diacylglycerol@C: unimod mod=576.511761, formula mass=576.5117292
# Didehydroretinylidene@K: unimod mod=264.187801, formula mass=264.1877904
# DimethylamineGMBS@C: unimod mod=267.158292, formula mass=267.1582785
# Dipyrrolylmethanemethyl@C: unimod mod=418.137616, formula mass=418.1376004
# DyLight-maleimide@C: unimod mod=940.1999, formula mass=940.1998651
# EDEDTIDVFQQQTGG@K: unimod mod=1662.700924, formula mass=1662.7008498
# EDT-iodoacetyl-PEO-biotin@S: unimod mod=490.174218, formula mass=490.1741956
# EDT-iodoacetyl-PEO-biotin@T: unimod mod=490.174218, formula mass=490.1741956
# EDT-maleimide-PEO-biotin@S: unimod mod=601.206246, formula mass=601.2062199999999
# EDT-maleimide-PEO-biotin@T: unimod mod=601.206246, formula mass=601.2062199999999
# EEEDVIEVYQEQTGG@K: unimod mod=1705.73189, formula mass=1705.7318137000002
# EGCG1@C: unimod mod=456.069261, formula mass=456.0692487
# EQAT@C: unimod mod=184.157563, formula mass=184.1575525
# EQIGG@K: unimod mod=484.228162, formula mass=484.2281392
# ESP@Any N-term: unimod mod=338.177647, formula mass=338.17763059999993
# ESP@K: unimod mod=338.177647, formula mass=338.17763059999993
# ExacTagAmine@K: unimod mod=1046.347854, formula mass=1046.3478203
# ExacTagThiol@C: unimod mod=972.365219, formula mass=972.3651870000001
# FAD@C: unimod mod=783.141486, formula mass=783.1414569
# FAD@H: unimod mod=783.141486, formula mass=783.1414569
# FAD@Y: unimod mod=783.141486, formula mass=783.1414569
# FMN@S: unimod mod=438.094051, formula mass=438.094035
# FMN@T: unimod mod=438.094051, formula mass=438.094035
# FMNC@C: unimod mod=456.104615, formula mass=456.1045983000001
# FMNH@C: unimod mod=454.088965, formula mass=454.0889491
# FMNH@H: unimod mod=454.088965, formula mass=454.0889491
# FNEM@C: unimod mod=427.069202, formula mass=427.06919170000003
# FP-Biotin@K: unimod mod=572.316129, formula mass=572.3161007
# FP-Biotin@S: unimod mod=572.316129, formula mass=572.3161007
# FP-Biotin@T: unimod mod=572.316129, formula mass=572.3161007
# FP-Biotin@Y: unimod mod=572.316129, formula mass=572.3161007
# FTC@C: unimod mod=421.073241, formula mass=421.0732291
# FTC@K: unimod mod=421.073241, formula mass=421.0732291
# FTC@P: unimod mod=421.073241, formula mass=421.0732291
# FTC@R: unimod mod=421.073241, formula mass=421.0732291
# FTC@S: unimod mod=421.073241, formula mass=421.0732291
# Farnesyl@C: unimod mod=204.187801, formula mass=204.18779039999998
# Fluorescein-tyramine@Y: unimod mod=493.116152, formula mass=493.11613930000004
# GGQ@K: unimod mod=242.101505, formula mass=242.10149360000003
# GNLLFLACYCIGG@K: unimod mod=1324.6308, formula mass=1324.6307395000001
# GeranylGeranyl@C: unimod mod=272.250401, formula mass=272.2503872
# GluGlu@E: unimod mod=258.085186, formula mass=258.0851754
# GluGlu@Protein C-term: unimod mod=258.085186, formula mass=258.0851754
# GluGluGlu@E: unimod mod=387.127779, formula mass=387.12776310000004
# GluGluGlu@Protein C-term: unimod mod=387.127779, formula mass=387.12776310000004
# GluGluGluGlu@E: unimod mod=516.170373, formula mass=516.1703508
# GluGluGluGlu@Protein C-term: unimod mod=516.170373, formula mass=516.1703508
# Glucosylgalactosyl@K: unimod mod=340.100562, formula mass=340.10054710000003
# Glutathione@C: unimod mod=305.068156, formula mass=305.06814319999995
# HNE-BAHAH@C: unimod mod=511.319226, formula mass=511.3191994
# HNE-BAHAH@H: unimod mod=511.319226, formula mass=511.3191994
# HNE-BAHAH@K: unimod mod=511.319226, formula mass=511.3191994
# Heme@C: unimod mod=616.177295, formula mass=616.1772754
# Heme@H: unimod mod=616.177295, formula mass=616.1772754
# Hex(1)HexA(1)@S: unimod mod=338.084912, formula mass=338.0848979
# Hex(1)HexA(1)@T: unimod mod=338.084912, formula mass=338.0848979
# Hex(1)HexA(1)HexNAc(1)@S: unimod mod=541.164284, formula mass=541.1642614
# Hex(1)HexA(1)HexNAc(1)@T: unimod mod=541.164284, formula mass=541.1642614
# Hex(1)HexA(1)HexNAc(2)@S: unimod mod=744.243657, formula mass=744.2436249
# Hex(1)HexA(1)HexNAc(2)@T: unimod mod=744.243657, formula mass=744.2436249
# Hex(1)HexNAc(1)@N: unimod mod=365.132196, formula mass=365.13217999999995
# Hex(1)HexNAc(1)@S: unimod mod=365.132196, formula mass=365.13217999999995
# Hex(1)HexNAc(1)@T: unimod mod=365.132196, formula mass=365.13217999999995
# Hex(1)HexNAc(1)Kdn(1)Sulf(1)@S: unimod mod=695.157878, formula mass=695.1578495000001
# Hex(1)HexNAc(1)Kdn(1)Sulf(1)@T: unimod mod=695.157878, formula mass=695.1578495000001
# Hex(1)HexNAc(1)NeuAc(1)@N: unimod mod=656.227613, formula mass=656.2275842
# Hex(1)HexNAc(1)NeuAc(1)@S: unimod mod=656.227613, formula mass=656.2275842
# Hex(1)HexNAc(1)NeuAc(1)@T: unimod mod=656.227613, formula mass=656.2275842
# Hex(1)HexNAc(1)NeuAc(1)Ac(1)@S: unimod mod=698.238177, formula mass=698.2381475
# Hex(1)HexNAc(1)NeuAc(1)Ac(1)@T: unimod mod=698.238177, formula mass=698.2381475
# Hex(1)HexNAc(1)NeuAc(1)NeuGc(1)@S: unimod mod=963.317944, formula mass=963.3179025
# Hex(1)HexNAc(1)NeuAc(1)NeuGc(1)@T: unimod mod=963.317944, formula mass=963.3179025
# Hex(1)HexNAc(1)NeuAc(1)Sulf(1)@S: unimod mod=736.184427, formula mass=736.1843965
# Hex(1)HexNAc(1)NeuAc(1)Sulf(1)@T: unimod mod=736.184427, formula mass=736.1843965
# Hex(1)HexNAc(1)NeuAc(2)@N: unimod mod=947.323029, formula mass=947.3229884
# Hex(1)HexNAc(1)NeuAc(2)@S: unimod mod=947.323029, formula mass=947.3229884
# Hex(1)HexNAc(1)NeuAc(2)@T: unimod mod=947.323029, formula mass=947.3229884
# Hex(1)HexNAc(1)NeuAc(2)Ac(1)@S: unimod mod=989.333594, formula mass=989.3335517
# Hex(1)HexNAc(1)NeuAc(2)Ac(1)@T: unimod mod=989.333594, formula mass=989.3335517
# Hex(1)HexNAc(1)NeuAc(2)Ac(2)@S: unimod mod=1031.344159, formula mass=1031.344115
# Hex(1)HexNAc(1)NeuAc(2)Ac(2)@T: unimod mod=1031.344159, formula mass=1031.344115
# Hex(1)HexNAc(1)NeuAc(3)@S: unimod mod=1238.418446, formula mass=1238.4183926
# Hex(1)HexNAc(1)NeuAc(3)@T: unimod mod=1238.418446, formula mass=1238.4183926
# Hex(1)HexNAc(1)NeuGc(1)@S: unimod mod=672.222527, formula mass=672.2224983000001
# Hex(1)HexNAc(1)NeuGc(1)@T: unimod mod=672.222527, formula mass=672.2224983000001
# Hex(1)HexNAc(1)NeuGc(2)@S: unimod mod=979.312859, formula mass=979.3128166
# Hex(1)HexNAc(1)NeuGc(2)@T: unimod mod=979.312859, formula mass=979.3128166
# Hex(1)HexNAc(1)NeuGc(3)@S: unimod mod=1286.40319, formula mass=1286.4031349
# Hex(1)HexNAc(1)NeuGc(3)@T: unimod mod=1286.40319, formula mass=1286.4031349
# Hex(1)HexNAc(1)NeuGc(4)@S: unimod mod=1593.493521, formula mass=1593.4934532000002
# Hex(1)HexNAc(1)NeuGc(4)@T: unimod mod=1593.493521, formula mass=1593.4934532000002
# Hex(1)HexNAc(1)NeuGc(5)@S: unimod mod=1900.583852, formula mass=1900.5837715
# Hex(1)HexNAc(1)NeuGc(5)@T: unimod mod=1900.583852, formula mass=1900.5837715
# Hex(1)HexNAc(1)Phos(1)@S: unimod mod=445.098527, formula mass=445.0985089
# Hex(1)HexNAc(1)Phos(1)@T: unimod mod=445.098527, formula mass=445.0985089
# Hex(1)HexNAc(1)Sulf(1)@S: unimod mod=445.089011, formula mass=445.0889923
# Hex(1)HexNAc(1)Sulf(1)@T: unimod mod=445.089011, formula mass=445.0889923
# Hex(1)HexNAc(1)dHex(1)@N: unimod mod=511.190105, formula mass=511.19008240000005
# Hex(1)HexNAc(1)dHex(1)@S: unimod mod=511.190105, formula mass=511.19008240000005
# Hex(1)HexNAc(1)dHex(1)@T: unimod mod=511.190105, formula mass=511.19008240000005
# Hex(1)HexNAc(1)dHex(1)Me(1)@S: unimod mod=525.205755, formula mass=525.2057316
# Hex(1)HexNAc(1)dHex(1)Me(1)@T: unimod mod=525.205755, formula mass=525.2057316
# Hex(1)HexNAc(1)dHex(1)Me(2)@S: unimod mod=539.221405, formula mass=539.2213808
# Hex(1)HexNAc(1)dHex(1)Me(2)@T: unimod mod=539.221405, formula mass=539.2213808
# Hex(1)HexNAc(2)@N: unimod mod=568.211569, formula mass=568.2115435000001
# Hex(1)HexNAc(2)@S: unimod mod=568.211569, formula mass=568.2115435000001
# Hex(1)HexNAc(2)@T: unimod mod=568.211569, formula mass=568.2115435000001
# Hex(1)HexNAc(2)NeuAc(1)@S: unimod mod=859.306985, formula mass=859.3069477
# Hex(1)HexNAc(2)NeuAc(1)@T: unimod mod=859.306985, formula mass=859.3069477
# Hex(1)HexNAc(2)NeuAc(1)Sulf(1)@S: unimod mod=939.2638, formula mass=939.26376
# Hex(1)HexNAc(2)NeuAc(1)Sulf(1)@T: unimod mod=939.2638, formula mass=939.26376
# Hex(1)HexNAc(2)NeuAc(2)@S: unimod mod=1150.402402, formula mass=1150.4023519
# Hex(1)HexNAc(2)NeuAc(2)@T: unimod mod=1150.402402, formula mass=1150.4023519
# Hex(1)HexNAc(2)NeuAc(2)Sulf(1)@S: unimod mod=1230.359217, formula mass=1230.3591642
# Hex(1)HexNAc(2)NeuAc(2)Sulf(1)@T: unimod mod=1230.359217, formula mass=1230.3591642
# Hex(1)HexNAc(2)NeuGc(1)@S: unimod mod=875.3019, formula mass=875.3018618
# Hex(1)HexNAc(2)NeuGc(1)@T: unimod mod=875.3019, formula mass=875.3018618
# Hex(1)HexNAc(2)Pent(1)@N: unimod mod=700.253828, formula mass=700.2537967000001
# Hex(1)HexNAc(2)Sulf(1)@S: unimod mod=648.168383, formula mass=648.1683558
# Hex(1)HexNAc(2)Sulf(1)@T: unimod mod=648.168383, formula mass=648.1683558
# Hex(1)HexNAc(2)dHex(1)@N: unimod mod=714.269478, formula mass=714.2694458999999
# Hex(1)HexNAc(2)dHex(1)@S: unimod mod=714.269478, formula mass=714.2694458999999
# Hex(1)HexNAc(2)dHex(1)@T: unimod mod=714.269478, formula mass=714.2694458999999
# Hex(1)HexNAc(2)dHex(1)Pent(1)@N: unimod mod=846.311736, formula mass=846.3116990999999
# Hex(1)HexNAc(2)dHex(2)@N: unimod mod=860.327386, formula mass=860.3273483
# Hex(1)HexNAc(2)dHex(2)@S: unimod mod=860.327386, formula mass=860.3273483
# Hex(1)HexNAc(2)dHex(2)@T: unimod mod=860.327386, formula mass=860.3273483
# Hex(1)HexNAc(2)dHex(2)Sulf(1)@S: unimod mod=940.284201, formula mass=940.2841606000001
# Hex(1)HexNAc(2)dHex(2)Sulf(1)@T: unimod mod=940.284201, formula mass=940.2841606000001
# Hex(1)HexNAc(3)@S: unimod mod=771.290941, formula mass=771.2909070000001
# Hex(1)HexNAc(3)@T: unimod mod=771.290941, formula mass=771.2909070000001
# Hex(1)HexNAc(3)NeuAc(1)@S: unimod mod=1062.386358, formula mass=1062.3863112
# Hex(1)HexNAc(3)NeuAc(1)@T: unimod mod=1062.386358, formula mass=1062.3863112
# Hex(1)HexNAc(3)NeuAc(2)@S: unimod mod=1353.481775, formula mass=1353.4817154
# Hex(1)HexNAc(3)NeuAc(2)@T: unimod mod=1353.481775, formula mass=1353.4817154
# Hex(1)HexNAc(3)NeuGc(1)@S: unimod mod=1078.381273, formula mass=1078.3812253
# Hex(1)HexNAc(3)NeuGc(1)@T: unimod mod=1078.381273, formula mass=1078.3812253
# Hex(1)HexNAc(3)Sulf(1)@S: unimod mod=851.247756, formula mass=851.2477193000001
# Hex(1)HexNAc(3)Sulf(1)@T: unimod mod=851.247756, formula mass=851.2477193000001
# Hex(1)HexNAc(4)dHex(1)Sulf(1)@S: unimod mod=1200.385037, formula mass=1200.3849852
# Hex(1)HexNAc(4)dHex(1)Sulf(1)@T: unimod mod=1200.385037, formula mass=1200.3849852
# Hex(1)NeuAc(1)@S: unimod mod=453.14824, formula mass=453.1482207
# Hex(1)NeuAc(1)@T: unimod mod=453.14824, formula mass=453.1482207
# Hex(1)NeuAc(1)Pent(1)@S: unimod mod=585.190499, formula mass=585.1904739
# Hex(1)NeuAc(1)Pent(1)@T: unimod mod=585.190499, formula mass=585.1904739
# Hex(1)NeuGc(1)@S: unimod mod=469.143155, formula mass=469.1431348
# Hex(1)NeuGc(1)@T: unimod mod=469.143155, formula mass=469.1431348
# Hex(1)Pent(1)@S: unimod mod=294.095082, formula mass=294.0950697
# Hex(1)Pent(1)@T: unimod mod=294.095082, formula mass=294.0950697
# Hex(1)Pent(2)@S: unimod mod=426.137341, formula mass=426.1373229
# Hex(1)Pent(2)@T: unimod mod=426.137341, formula mass=426.1373229
# Hex(1)Pent(2)Me(1)@S: unimod mod=440.152991, formula mass=440.15297210000006
# Hex(1)Pent(2)Me(1)@T: unimod mod=440.152991, formula mass=440.15297210000006
# Hex(1)Pent(3)@S: unimod mod=558.1796, formula mass=558.1795761000001
# Hex(1)Pent(3)@T: unimod mod=558.1796, formula mass=558.1795761000001
# Hex(1)Pent(3)Me(1)@S: unimod mod=572.19525, formula mass=572.1952253
# Hex(1)Pent(3)Me(1)@T: unimod mod=572.19525, formula mass=572.1952253
# Hex(10)HexNAc(1)@N: unimod mod=1823.607608, formula mass=1823.6075285000002
# Hex(10)Phos(3)@S: unimod mod=1860.427228, formula mass=1860.4271517
# Hex(10)Phos(3)@T: unimod mod=1860.427228, formula mass=1860.4271517
# Hex(2)@K: unimod mod=324.105647, formula mass=324.105633
# Hex(2)@R: unimod mod=324.105647, formula mass=324.105633
# Hex(2)@S: unimod mod=324.105647, formula mass=324.105633
# Hex(2)@T: unimod mod=324.105647, formula mass=324.105633
# Hex(2)HexA(1)HexNAc(1)Sulf(1)@S: unimod mod=783.173922, formula mass=783.1738902000001
# Hex(2)HexA(1)HexNAc(1)Sulf(1)@T: unimod mod=783.173922, formula mass=783.1738902000001
# Hex(2)HexA(1)NeuAc(1)Pent(1)Sulf(1)@S: unimod mod=1003.232225, formula mass=1003.2321841
# Hex(2)HexA(1)NeuAc(1)Pent(1)Sulf(1)@T: unimod mod=1003.232225, formula mass=1003.2321841
# Hex(2)HexA(1)Pent(1)Sulf(1)@S: unimod mod=712.136808, formula mass=712.1367799000001
# Hex(2)HexA(1)Pent(1)Sulf(1)@T: unimod mod=712.136808, formula mass=712.1367799000001
# Hex(2)HexNAc(1)@N: unimod mod=527.18502, formula mass=527.1849965000001
# Hex(2)HexNAc(1)@S: unimod mod=527.18502, formula mass=527.1849965000001
# Hex(2)HexNAc(1)@T: unimod mod=527.18502, formula mass=527.1849965000001
# Hex(2)HexNAc(1)Me(1)@S: unimod mod=541.20067, formula mass=541.2006457
# Hex(2)HexNAc(1)Me(1)@T: unimod mod=541.20067, formula mass=541.2006457
# Hex(2)HexNAc(1)NeuGc(1)@S: unimod mod=834.275351, formula mass=834.2753147999999
# Hex(2)HexNAc(1)NeuGc(1)@T: unimod mod=834.275351, formula mass=834.2753147999999
# Hex(2)HexNAc(1)NeuGc(2)@S: unimod mod=1141.365682, formula mass=1141.3656331
# Hex(2)HexNAc(1)NeuGc(2)@T: unimod mod=1141.365682, formula mass=1141.3656331
# Hex(2)HexNAc(1)NeuGc(3)@S: unimod mod=1448.456013, formula mass=1448.4559514
# Hex(2)HexNAc(1)NeuGc(3)@T: unimod mod=1448.456013, formula mass=1448.4559514
# Hex(2)HexNAc(1)NeuGc(4)@S: unimod mod=1755.546345, formula mass=1755.5462696999998
# Hex(2)HexNAc(1)NeuGc(4)@T: unimod mod=1755.546345, formula mass=1755.5462696999998
# Hex(2)HexNAc(1)Pent(1)HexA(1)@S: unimod mod=835.259366, formula mass=835.2593311
# Hex(2)HexNAc(1)Pent(1)HexA(1)@T: unimod mod=835.259366, formula mass=835.2593311
# Hex(2)HexNAc(1)Sulf(1)@S: unimod mod=607.141834, formula mass=607.1418088
# Hex(2)HexNAc(1)Sulf(1)@T: unimod mod=607.141834, formula mass=607.1418088
# Hex(2)HexNAc(2)@N: unimod mod=730.264392, formula mass=730.2643599999999
# Hex(2)HexNAc(2)@S: unimod mod=730.264392, formula mass=730.2643599999999
# Hex(2)HexNAc(2)@T: unimod mod=730.264392, formula mass=730.2643599999999
# Hex(2)HexNAc(2)NeuAc(1)@N: unimod mod=1021.359809, formula mass=1021.3597642
# Hex(2)HexNAc(2)NeuAc(1)@S: unimod mod=1021.359809, formula mass=1021.3597642
# Hex(2)HexNAc(2)NeuAc(1)@T: unimod mod=1021.359809, formula mass=1021.3597642
# Hex(2)HexNAc(2)NeuAc(1)Sulf(1)@S: unimod mod=1101.316623, formula mass=1101.3165765
# Hex(2)HexNAc(2)NeuAc(1)Sulf(1)@T: unimod mod=1101.316623, formula mass=1101.3165765
# Hex(2)HexNAc(2)NeuAc(2)@S: unimod mod=1312.455225, formula mass=1312.4551684
# Hex(2)HexNAc(2)NeuAc(2)@T: unimod mod=1312.455225, formula mass=1312.4551684
# Hex(2)HexNAc(2)NeuAc(2)Sulf(1)@S: unimod mod=1392.41204, formula mass=1392.4119807
# Hex(2)HexNAc(2)NeuAc(2)Sulf(1)@T: unimod mod=1392.41204, formula mass=1392.4119807
# Hex(2)HexNAc(2)NeuGc(1)@S: unimod mod=1037.354723, formula mass=1037.3546783
# Hex(2)HexNAc(2)NeuGc(1)@T: unimod mod=1037.354723, formula mass=1037.3546783
# Hex(2)HexNAc(2)Pent(1)@N: unimod mod=862.306651, formula mass=862.3066131999999
# Hex(2)HexNAc(2)Sulf(1)@S: unimod mod=810.221207, formula mass=810.2211723
# Hex(2)HexNAc(2)Sulf(1)@T: unimod mod=810.221207, formula mass=810.2211723
# Hex(2)HexNAc(2)dHex(1)@N: unimod mod=876.322301, formula mass=876.3222624
# Hex(2)HexNAc(2)dHex(1)@S: unimod mod=876.322301, formula mass=876.3222624
# Hex(2)HexNAc(2)dHex(1)@T: unimod mod=876.322301, formula mass=876.3222624
# Hex(2)HexNAc(3)@N: unimod mod=933.343765, formula mass=933.3437235
# Hex(2)HexNAc(3)@S: unimod mod=933.343765, formula mass=933.3437235
# Hex(2)HexNAc(3)@T: unimod mod=933.343765, formula mass=933.3437235
# Hex(2)HexNAc(3)NeuAc(1)NeuGc(1)@S: unimod mod=1531.529513, formula mass=1531.529446
# Hex(2)HexNAc(3)NeuAc(1)NeuGc(1)@T: unimod mod=1531.529513, formula mass=1531.529446
# Hex(2)HexNAc(3)NeuAc(1)Sulf(1)@S: unimod mod=1304.395996, formula mass=1304.39594
# Hex(2)HexNAc(3)NeuAc(1)Sulf(1)@T: unimod mod=1304.395996, formula mass=1304.39594
# Hex(2)HexNAc(3)NeuAc(2)@S: unimod mod=1515.534598, formula mass=1515.5345319
# Hex(2)HexNAc(3)NeuAc(2)@T: unimod mod=1515.534598, formula mass=1515.5345319
# Hex(2)HexNAc(3)NeuAc(3)@S: unimod mod=1806.630015, formula mass=1806.6299361000001
# Hex(2)HexNAc(3)NeuAc(3)@T: unimod mod=1806.630015, formula mass=1806.6299361000001
# Hex(2)HexNAc(3)NeuGc(1)@S: unimod mod=1240.434096, formula mass=1240.4340418
# Hex(2)HexNAc(3)NeuGc(1)@T: unimod mod=1240.434096, formula mass=1240.4340418
# Hex(2)HexNAc(3)NeuGc(2)@S: unimod mod=1547.524427, formula mass=1547.5243601
# Hex(2)HexNAc(3)NeuGc(2)@T: unimod mod=1547.524427, formula mass=1547.5243601
# Hex(2)HexNAc(3)NeuGc(3)@S: unimod mod=1854.614759, formula mass=1854.6146784
# Hex(2)HexNAc(3)NeuGc(3)@T: unimod mod=1854.614759, formula mass=1854.6146784
# Hex(2)HexNAc(3)Sulf(1)@S: unimod mod=1013.300579, formula mass=1013.3005358
# Hex(2)HexNAc(3)Sulf(1)@T: unimod mod=1013.300579, formula mass=1013.3005358
# Hex(2)HexNAc(4)@N: unimod mod=1136.423137, formula mass=1136.4230870000001
# Hex(2)HexNAc(4)@S: unimod mod=1136.423137, formula mass=1136.4230870000001
# Hex(2)HexNAc(4)@T: unimod mod=1136.423137, formula mass=1136.4230870000001
# Hex(2)HexNAc(4)NeuAc(1)@S: unimod mod=1427.518554, formula mass=1427.5184912
# Hex(2)HexNAc(4)NeuAc(1)@T: unimod mod=1427.518554, formula mass=1427.5184912
# Hex(2)HexNAc(5)@S: unimod mod=1339.50251, formula mass=1339.5024505000001
# Hex(2)HexNAc(5)@T: unimod mod=1339.50251, formula mass=1339.5024505000001
# Hex(2)NeuAc(1)@S: unimod mod=615.201064, formula mass=615.2010372
# Hex(2)NeuAc(1)@T: unimod mod=615.201064, formula mass=615.2010372
# Hex(2)Pent(2)@S: unimod mod=588.190165, formula mass=588.1901394
# Hex(2)Pent(2)@T: unimod mod=588.190165, formula mass=588.1901394
# Hex(2)Pent(2)Me(1)@S: unimod mod=602.205815, formula mass=602.2057886
# Hex(2)Pent(2)Me(1)@T: unimod mod=602.205815, formula mass=602.2057886
# Hex(2)Sulf(1)@S: unimod mod=404.062462, formula mass=404.0624453
# Hex(2)Sulf(1)@T: unimod mod=404.062462, formula mass=404.0624453
# Hex(3)@N: unimod mod=486.158471, formula mass=486.1584495
# Hex(3)@S: unimod mod=486.158471, formula mass=486.1584495
# Hex(3)@T: unimod mod=486.158471, formula mass=486.1584495
# Hex(3)HexNAc(1)@N: unimod mod=689.237843, formula mass=689.237813
# Hex(3)HexNAc(1)@S: unimod mod=689.237843, formula mass=689.237813
# Hex(3)HexNAc(1)@T: unimod mod=689.237843, formula mass=689.237813
# Hex(3)HexNAc(1)HexA(1)@S: unimod mod=865.269931, formula mass=865.2698944000001
# Hex(3)HexNAc(1)HexA(1)@T: unimod mod=865.269931, formula mass=865.2698944000001
# Hex(3)HexNAc(1)Me(1)@S: unimod mod=703.253493, formula mass=703.2534622000001
# Hex(3)HexNAc(1)Me(1)@T: unimod mod=703.253493, formula mass=703.2534622000001
# Hex(3)HexNAc(1)Pent(1)@N: unimod mod=821.280102, formula mass=821.2800662
# Hex(3)HexNAc(2)@N: unimod mod=892.317216, formula mass=892.3171765
# Hex(3)HexNAc(2)@S: unimod mod=892.317216, formula mass=892.3171765
# Hex(3)HexNAc(2)@T: unimod mod=892.317216, formula mass=892.3171765
# Hex(3)HexNAc(2)NeuAc(1)@N: unimod mod=1183.412632, formula mass=1183.4125807
# Hex(3)HexNAc(2)NeuAc(2)@S: unimod mod=1474.508049, formula mass=1474.5079848999999
# Hex(3)HexNAc(2)NeuAc(2)@T: unimod mod=1474.508049, formula mass=1474.5079848999999
# Hex(3)HexNAc(2)Pent(1)@N: unimod mod=1024.359475, formula mass=1024.3594297
# Hex(3)HexNAc(2)Phos(1)@N: unimod mod=972.283547, formula mass=972.2835054
# Hex(3)HexNAc(3)@N: unimod mod=1095.396588, formula mass=1095.3965400000002
# Hex(3)HexNAc(3)@S: unimod mod=1095.396588, formula mass=1095.3965400000002
# Hex(3)HexNAc(3)@T: unimod mod=1095.396588, formula mass=1095.3965400000002
# Hex(3)HexNAc(3)NeuAc(1)@S: unimod mod=1386.492005, formula mass=1386.4919442
# Hex(3)HexNAc(3)NeuAc(1)@T: unimod mod=1386.492005, formula mass=1386.4919442
# Hex(3)HexNAc(3)NeuAc(1)Sulf(1)@S: unimod mod=1466.44882, formula mass=1466.4487565000002
# Hex(3)HexNAc(3)NeuAc(1)Sulf(1)@T: unimod mod=1466.44882, formula mass=1466.4487565000002
# Hex(3)HexNAc(3)NeuAc(2)@S: unimod mod=1677.587422, formula mass=1677.5873484
# Hex(3)HexNAc(3)NeuAc(2)@T: unimod mod=1677.587422, formula mass=1677.5873484
# Hex(3)HexNAc(3)NeuAc(2)Sulf(1)@S: unimod mod=1757.544236, formula mass=1757.5441607
# Hex(3)HexNAc(3)NeuAc(2)Sulf(1)@T: unimod mod=1757.544236, formula mass=1757.5441607
# Hex(3)HexNAc(3)NeuAc(3)@S: unimod mod=1968.682838, formula mass=1968.6827526000002
# Hex(3)HexNAc(3)NeuAc(3)@T: unimod mod=1968.682838, formula mass=1968.6827526000002
# Hex(3)HexNAc(3)NeuGc(1)@S: unimod mod=1402.48692, formula mass=1402.4868583
# Hex(3)HexNAc(3)NeuGc(1)@T: unimod mod=1402.48692, formula mass=1402.4868583
# Hex(3)HexNAc(3)NeuGc(1)Sulf(1)@S: unimod mod=1482.443734, formula mass=1482.4436706
# Hex(3)HexNAc(3)NeuGc(1)Sulf(1)@T: unimod mod=1482.443734, formula mass=1482.4436706
# Hex(3)HexNAc(3)Pent(1)@N: unimod mod=1227.438847, formula mass=1227.4387932
# Hex(3)HexNAc(3)Sulf(1)@N: unimod mod=1175.353403, formula mass=1175.3533523
# Hex(3)HexNAc(3)Sulf(1)@S: unimod mod=1175.353403, formula mass=1175.3533523
# Hex(3)HexNAc(3)Sulf(1)@T: unimod mod=1175.353403, formula mass=1175.3533523
# Hex(3)HexNAc(4)@N: unimod mod=1298.475961, formula mass=1298.4759035000002
# Hex(3)HexNAc(4)@S: unimod mod=1298.475961, formula mass=1298.4759035000002
# Hex(3)HexNAc(4)@T: unimod mod=1298.475961, formula mass=1298.4759035000002
# Hex(3)HexNAc(4)NeuAc(1)@N: unimod mod=1589.571378, formula mass=1589.5713077
# Hex(3)HexNAc(4)NeuAc(2)@N: unimod mod=1880.666794, formula mass=1880.6667118999999
# Hex(3)HexNAc(4)Pent(1)@N: unimod mod=1430.51822, formula mass=1430.5181567
# Hex(3)HexNAc(4)Sulf(1)@N: unimod mod=1378.432776, formula mass=1378.4327158
# Hex(3)HexNAc(5)@N: unimod mod=1501.555334, formula mass=1501.555267
# Hex(3)HexNAc(5)@S: unimod mod=1501.555334, formula mass=1501.555267
# Hex(3)HexNAc(5)@T: unimod mod=1501.555334, formula mass=1501.555267
# Hex(3)HexNAc(5)NeuAc(1)@N: unimod mod=1792.65075, formula mass=1792.6506712
# Hex(3)HexNAc(5)Sulf(1)@N: unimod mod=1581.512148, formula mass=1581.5120792999999
# Hex(3)HexNAc(6)@N: unimod mod=1704.634706, formula mass=1704.6346305
# Hex(3)HexNAc(6)@S: unimod mod=1704.634706, formula mass=1704.6346305
# Hex(3)HexNAc(6)@T: unimod mod=1704.634706, formula mass=1704.6346305
# Hex(3)HexNAc(6)NeuAc(1)@N: unimod mod=1995.730123, formula mass=1995.7300347
# Hex(3)HexNAc(6)Sulf(1)@N: unimod mod=1784.591521, formula mass=1784.5914427999999
# Hex(3)HexNAc(6)Sulf(2)@N: unimod mod=1864.548335, formula mass=1864.5482551
# Hex(3)HexNAc(7)@N: unimod mod=1907.714079, formula mass=1907.713994
# Hex(3)HexNAc(7)Sulf(1)@N: unimod mod=1987.670893, formula mass=1987.6708062999999
# Hex(4)@S: unimod mod=648.211294, formula mass=648.211266
# Hex(4)@T: unimod mod=648.211294, formula mass=648.211266
# Hex(4)HexA(1)@S: unimod mod=824.243382, formula mass=824.2433474
# Hex(4)HexA(1)@T: unimod mod=824.243382, formula mass=824.2433474
# Hex(4)HexA(1)HexNAc(1)@S: unimod mod=1027.322755, formula mass=1027.3227109
# Hex(4)HexA(1)HexNAc(1)@T: unimod mod=1027.322755, formula mass=1027.3227109
# Hex(4)HexNAc(1)@N: unimod mod=851.290667, formula mass=851.2906295
# Hex(4)HexNAc(1)@S: unimod mod=851.290667, formula mass=851.2906295
# Hex(4)HexNAc(1)@T: unimod mod=851.290667, formula mass=851.2906295
# Hex(4)HexNAc(2)@N: unimod mod=1054.370039, formula mass=1054.3699930000002
# Hex(4)HexNAc(2)NeuAc(1)@N: unimod mod=1345.465456, formula mass=1345.4653972
# Hex(4)HexNAc(2)NeuAc(1)@S: unimod mod=1345.465456, formula mass=1345.4653972
# Hex(4)HexNAc(2)NeuAc(1)@T: unimod mod=1345.465456, formula mass=1345.4653972
# Hex(4)HexNAc(2)Pent(1)@N: unimod mod=1186.412298, formula mass=1186.4122462
# Hex(4)HexNAc(3)@N: unimod mod=1257.449412, formula mass=1257.4493565000002
# Hex(4)HexNAc(3)@S: unimod mod=1257.449412, formula mass=1257.4493565000002
# Hex(4)HexNAc(3)@T: unimod mod=1257.449412, formula mass=1257.4493565000002
# Hex(4)HexNAc(3)NeuAc(1)@N: unimod mod=1548.544828, formula mass=1548.5447606999999
# Hex(4)HexNAc(3)NeuAc(1)@S: unimod mod=1548.544828, formula mass=1548.5447606999999
# Hex(4)HexNAc(3)NeuAc(1)@T: unimod mod=1548.544828, formula mass=1548.5447606999999
# Hex(4)HexNAc(3)NeuAc(2)@N: unimod mod=1839.640245, formula mass=1839.6401649
# Hex(4)HexNAc(3)NeuGc(1)@N: unimod mod=1564.539743, formula mass=1564.5396747999998
# Hex(4)HexNAc(3)Pent(1)@N: unimod mod=1389.491671, formula mass=1389.4916097
# Hex(4)HexNAc(4)@N: unimod mod=1460.528784, formula mass=1460.5287199999998
# Hex(4)HexNAc(4)@S: unimod mod=1460.528784, formula mass=1460.5287199999998
# Hex(4)HexNAc(4)@T: unimod mod=1460.528784, formula mass=1460.5287199999998
# Hex(4)HexNAc(4)Me(2)Pent(1)@N: unimod mod=1620.602343, formula mass=1620.6022716
# Hex(4)HexNAc(4)NeuAc(1)@N: unimod mod=1751.624201, formula mass=1751.6241242
# Hex(4)HexNAc(4)NeuAc(1)@S: unimod mod=1751.624201, formula mass=1751.6241242
# Hex(4)HexNAc(4)NeuAc(1)@T: unimod mod=1751.624201, formula mass=1751.6241242
# Hex(4)HexNAc(4)NeuAc(1)Sulf(2)@S: unimod mod=1911.53783, formula mass=1911.5377488
# Hex(4)HexNAc(4)NeuAc(1)Sulf(2)@T: unimod mod=1911.53783, formula mass=1911.5377488
# Hex(4)HexNAc(4)NeuAc(1)Sulf(3)@S: unimod mod=1991.494645, formula mass=1991.4945611
# Hex(4)HexNAc(4)NeuAc(1)Sulf(3)@T: unimod mod=1991.494645, formula mass=1991.4945611
# Hex(4)HexNAc(4)NeuGc(1)@N: unimod mod=1767.619116, formula mass=1767.6190383
# Hex(4)HexNAc(4)NeuGc(1)@S: unimod mod=1767.619116, formula mass=1767.6190383
# Hex(4)HexNAc(4)NeuGc(1)@T: unimod mod=1767.619116, formula mass=1767.6190383
# Hex(4)HexNAc(4)NeuGc(1)Sulf(2)@S: unimod mod=1927.532745, formula mass=1927.5326629
# Hex(4)HexNAc(4)NeuGc(1)Sulf(2)@T: unimod mod=1927.532745, formula mass=1927.5326629
# Hex(4)HexNAc(4)Pent(1)@N: unimod mod=1592.571043, formula mass=1592.5709732
# Hex(4)HexNAc(4)Sulf(1)@N: unimod mod=1540.485599, formula mass=1540.4855323
# Hex(4)HexNAc(4)Sulf(2)@S: unimod mod=1620.442414, formula mass=1620.4423446
# Hex(4)HexNAc(4)Sulf(2)@T: unimod mod=1620.442414, formula mass=1620.4423446
# Hex(4)HexNAc(5)@N: unimod mod=1663.608157, formula mass=1663.6080835
# Hex(4)HexNAc(5)NeuAc(1)@N: unimod mod=1954.703574, formula mass=1954.7034877
# Hex(4)HexNAc(5)Sulf(1)@N: unimod mod=1743.564972, formula mass=1743.5648958
# Hex(4)HexNAc(6)@N: unimod mod=1866.68753, formula mass=1866.687447
# Hex(4)Phos(1)@S: unimod mod=728.177625, formula mass=728.1775949
# Hex(4)Phos(1)@T: unimod mod=728.177625, formula mass=728.1775949
# Hex(5)@S: unimod mod=810.264117, formula mass=810.2640825000001
# Hex(5)@T: unimod mod=810.264117, formula mass=810.2640825000001
# Hex(5)HexA(1)@S: unimod mod=986.296206, formula mass=986.2961639
# Hex(5)HexA(1)@T: unimod mod=986.296206, formula mass=986.2961639
# Hex(5)HexNAc(1)@N: unimod mod=1013.34349, formula mass=1013.3434460000001
# Hex(5)HexNAc(1)@S: unimod mod=1013.34349, formula mass=1013.3434460000001
# Hex(5)HexNAc(1)@T: unimod mod=1013.34349, formula mass=1013.3434460000001
# Hex(5)HexNAc(2)@N: unimod mod=1216.422863, formula mass=1216.4228095
# Hex(5)HexNAc(2)Phos(1)@N: unimod mod=1296.389194, formula mass=1296.3891384000003
# Hex(5)HexNAc(3)@N: unimod mod=1419.502235, formula mass=1419.502173
# Hex(5)HexNAc(3)Pent(1)@N: unimod mod=1551.544494, formula mass=1551.5444262
# Hex(5)HexNAc(4)@N: unimod mod=1622.581608, formula mass=1622.5815364999999
# Hex(5)HexNAc(4)@S: unimod mod=1622.581608, formula mass=1622.5815364999999
# Hex(5)HexNAc(4)@T: unimod mod=1622.581608, formula mass=1622.5815364999999
# Hex(5)HexNAc(4)Me(2)Pent(1)@N: unimod mod=1782.655167, formula mass=1782.6550881
# Hex(5)HexNAc(4)NeuAc(1)@N: unimod mod=1913.677025, formula mass=1913.6769407000002
# Hex(5)HexNAc(4)NeuAc(1)Ac(1)@N: unimod mod=1955.687589, formula mass=1955.687504
# Hex(5)HexNAc(4)NeuAc(1)Ac(2)@N: unimod mod=1997.698154, formula mass=1997.6980673
# Hex(5)HexNAc(4)NeuAc(1)Sulf(1)@N: unimod mod=1993.633839, formula mass=1993.633753
# Hex(5)HexNAc(4)NeuAc(2)@N: unimod mod=2204.772441, formula mass=2204.7723449
# Hex(5)HexNAc(4)NeuGc(1)@N: unimod mod=1929.671939, formula mass=1929.6718548
# Hex(5)HexNAc(4)Sulf(1)@N: unimod mod=1702.538423, formula mass=1702.5383488
# Hex(5)HexNAc(5)@N: unimod mod=1825.660981, formula mass=1825.6609
# Hex(5)HexNAc(5)@S: unimod mod=1825.660981, formula mass=1825.6609
# Hex(5)HexNAc(5)@T: unimod mod=1825.660981, formula mass=1825.6609
# Hex(5)Phos(1)@S: unimod mod=890.230448, formula mass=890.2304114
# Hex(5)Phos(1)@T: unimod mod=890.230448, formula mass=890.2304114
# Hex(5)Phos(3)@S: unimod mod=1050.16311, formula mass=1050.1630691999999
# Hex(5)Phos(3)@T: unimod mod=1050.16311, formula mass=1050.1630691999999
# Hex(6)HexNAc(1)@N: unimod mod=1175.396314, formula mass=1175.3962625
# Hex(6)HexNAc(2)@N: unimod mod=1378.475686, formula mass=1378.475626
# Hex(6)HexNAc(2)Phos(1)@N: unimod mod=1458.442017, formula mass=1458.4419549
# Hex(6)HexNAc(3)@N: unimod mod=1581.555059, formula mass=1581.5549895
# Hex(6)HexNAc(3)Phos(1)@N: unimod mod=1661.52139, formula mass=1661.5213184
# Hex(6)HexNAc(4)@N: unimod mod=1784.634431, formula mass=1784.634353
# Hex(6)HexNAc(4)@S: unimod mod=1784.634431, formula mass=1784.634353
# Hex(6)HexNAc(4)@T: unimod mod=1784.634431, formula mass=1784.634353
# Hex(6)HexNAc(4)Me(3)@N: unimod mod=1826.681382, formula mass=1826.6813006
# Hex(6)HexNAc(4)Me(3)Pent(1)@N: unimod mod=1958.72364, formula mass=1958.7235538
# Hex(6)HexNAc(5)@N: unimod mod=1987.713804, formula mass=1987.7137165000001
# Hex(6)Phos(1)@S: unimod mod=1052.283272, formula mass=1052.2832279000002
# Hex(6)Phos(1)@T: unimod mod=1052.283272, formula mass=1052.2832279000002
# Hex(6)Phos(3)@S: unimod mod=1212.215934, formula mass=1212.2158857000002
# Hex(6)Phos(3)@T: unimod mod=1212.215934, formula mass=1212.2158857000002
# Hex(7)HexNAc(1)@N: unimod mod=1337.449137, formula mass=1337.449079
# Hex(7)HexNAc(2)@N: unimod mod=1540.52851, formula mass=1540.5284425
# Hex(7)HexNAc(2)Phos(1)@N: unimod mod=1620.494841, formula mass=1620.4947714
# Hex(7)HexNAc(2)Phos(2)@N: unimod mod=1700.461172, formula mass=1700.4611003
# Hex(7)HexNAc(3)@N: unimod mod=1743.607882, formula mass=1743.607806
# Hex(7)HexNAc(3)Phos(1)@N: unimod mod=1823.574213, formula mass=1823.5741349
# Hex(7)HexNAc(4)@N: unimod mod=1946.687255, formula mass=1946.6871695
# Hex(7)Phos(3)@S: unimod mod=1374.268757, formula mass=1374.2687022
# Hex(7)Phos(3)@T: unimod mod=1374.268757, formula mass=1374.2687022
# Hex(8)HexNAc(1)@N: unimod mod=1499.501961, formula mass=1499.5018955
# Hex(8)HexNAc(2)@N: unimod mod=1702.581333, formula mass=1702.581259
# Hex(8)Phos(3)@S: unimod mod=1536.321581, formula mass=1536.3215187
# Hex(8)Phos(3)@T: unimod mod=1536.321581, formula mass=1536.3215187
# Hex(9)@N: unimod mod=1458.475412, formula mass=1458.4753485
# Hex(9)HexNAc(1)@N: unimod mod=1661.554784, formula mass=1661.554712
# Hex(9)HexNAc(2)@N: unimod mod=1864.634157, formula mass=1864.6340755
# Hex(9)Phos(3)@S: unimod mod=1698.374404, formula mass=1698.3743352
# Hex(9)Phos(3)@T: unimod mod=1698.374404, formula mass=1698.3743352
# HexA(2)HexNAc(3)@S: unimod mod=961.302294, formula mass=961.3022533000001
# HexA(2)HexNAc(3)@T: unimod mod=961.302294, formula mass=961.3022533000001
# HexNAc(1)Kdn(2)@S: unimod mod=703.217108, formula mass=703.2170779
# HexNAc(1)Kdn(2)@T: unimod mod=703.217108, formula mass=703.2170779
# HexNAc(1)NeuAc(1)@S: unimod mod=494.174789, formula mass=494.17476769999996
# HexNAc(1)NeuAc(1)@T: unimod mod=494.174789, formula mass=494.17476769999996
# HexNAc(1)NeuGc(1)@S: unimod mod=510.169704, formula mass=510.1696818
# HexNAc(1)NeuGc(1)@T: unimod mod=510.169704, formula mass=510.1696818
# HexNAc(1)NeuGc(2)@S: unimod mod=817.260035, formula mass=817.2600001000001
# HexNAc(1)NeuGc(2)@T: unimod mod=817.260035, formula mass=817.2600001000001
# HexNAc(1)dHex(1)@N: unimod mod=349.137281, formula mass=349.1372659
# HexNAc(1)dHex(1)@S: unimod mod=349.137281, formula mass=349.1372659
# HexNAc(1)dHex(1)@T: unimod mod=349.137281, formula mass=349.1372659
# HexNAc(1)dHex(2)@N: unimod mod=495.19519, formula mass=495.1951683000001
# HexNAc(2)@N: unimod mod=406.158745, formula mass=406.158727
# HexNAc(2)@S: unimod mod=406.158745, formula mass=406.158727
# HexNAc(2)@T: unimod mod=406.158745, formula mass=406.158727
# HexNAc(2)NeuAc(1)@S: unimod mod=697.254162, formula mass=697.2541312000001
# HexNAc(2)NeuAc(1)@T: unimod mod=697.254162, formula mass=697.2541312000001
# HexNAc(2)NeuAc(1)Sulf(1)@S: unimod mod=777.210976, formula mass=777.2109435
# HexNAc(2)NeuAc(1)Sulf(1)@T: unimod mod=777.210976, formula mass=777.2109435
# HexNAc(2)NeuGc(1)@S: unimod mod=713.249076, formula mass=713.2490453
# HexNAc(2)NeuGc(1)@T: unimod mod=713.249076, formula mass=713.2490453
# HexNAc(2)Sulf(1)@S: unimod mod=486.11556, formula mass=486.11553929999997
# HexNAc(2)Sulf(1)@T: unimod mod=486.11556, formula mass=486.11553929999997
# HexNAc(2)dHex(1)@N: unimod mod=552.216654, formula mass=552.2166294
# HexNAc(2)dHex(2)@N: unimod mod=698.274563, formula mass=698.2745318
# HexNAc(3)@S: unimod mod=609.238118, formula mass=609.2380905
# HexNAc(3)@T: unimod mod=609.238118, formula mass=609.2380905
# HexNAc(3)Sulf(1)@S: unimod mod=689.194932, formula mass=689.1949028
# HexNAc(3)Sulf(1)@T: unimod mod=689.194932, formula mass=689.1949028
# HexNAc(4)@S: unimod mod=812.31749, formula mass=812.317454
# HexNAc(4)@T: unimod mod=812.31749, formula mass=812.317454
# HexNAc(5)@S: unimod mod=1015.396863, formula mass=1015.3968175
# HexNAc(5)@T: unimod mod=1015.396863, formula mass=1015.3968175
# Hydroxyfarnesyl@C: unimod mod=220.182715, formula mass=220.18270449999997
# Hydroxyheme@E: unimod mod=614.161645, formula mass=614.1616262
# IASD@C: unimod mod=452.034807, formula mass=452.0347928
# ICAT-C@C: unimod mod=227.126991, formula mass=227.1269801
# ICAT-D:2H(8)@C: unimod mod=450.275205, formula mass=450.2751897
# ICAT-D@C: unimod mod=442.224991, formula mass=442.22496970000003
# ICAT-G:2H(8)@C: unimod mod=494.30142, formula mass=494.3014022
# ICAT-G@C: unimod mod=486.251206, formula mass=486.25118219999996
# ICAT-H@C: unimod mod=345.097915, formula mass=345.0979029
# IED-Biotin@C: unimod mod=326.141261, formula mass=326.1412463
# IMEHex(2)NeuAc(1)@K: unimod mod=688.199683, formula mass=688.1996542
# Iminobiotin@Any N-term: unimod mod=225.093583, formula mass=225.09357269999998
# Iminobiotin@K: unimod mod=225.093583, formula mass=225.09357269999998
# IodoU-AMP@F: unimod mod=322.020217, formula mass=322.0202059
# IodoU-AMP@W: unimod mod=322.020217, formula mass=322.0202059
# IodoU-AMP@Y: unimod mod=322.020217, formula mass=322.0202059
# LG-Hlactam-K@K: unimod mod=348.193674, formula mass=348.19365930000004
# LG-Hlactam-K@Protein N-term: unimod mod=348.193674, formula mass=348.19365930000004
# LG-Hlactam-R@R: unimod mod=306.171876, formula mass=306.1718637
# LG-anhydrolactam@Any N-term: unimod mod=314.188195, formula mass=314.1881819
# LG-anhydrolactam@K: unimod mod=314.188195, formula mass=314.1881819
# LG-anhyropyrrole@Any N-term: unimod mod=298.19328, formula mass=298.1932678
# LG-anhyropyrrole@K: unimod mod=298.19328, formula mass=298.1932678
# LG-lactam-K@K: unimod mod=332.19876, formula mass=332.1987452
# LG-lactam-K@Protein N-term: unimod mod=332.19876, formula mass=332.1987452
# LG-lactam-R@R: unimod mod=290.176961, formula mass=290.1769496
# LG-pyrrole@Any N-term: unimod mod=316.203845, formula mass=316.2038311
# LG-pyrrole@C: unimod mod=316.203845, formula mass=316.2038311
# LG-pyrrole@K: unimod mod=316.203845, formula mass=316.2038311
# LRGG+dimethyl@K: unimod mod=411.259403, formula mass=411.2593806
# LRGG+methyl@K: unimod mod=397.243753, formula mass=397.2437314
# LRGG@K: unimod mod=383.228103, formula mass=383.2280822
# Label:13C(6)15N(4)+Dimethyl:2H(6)13C(2)@R: unimod mod=46.083939, formula mass=46.083949000000004
# Label:2H(9)13C(6)15N(2)@K: unimod mod=17.07069, formula mass=17.070701099999994
# Lysbiotinhydrazide@K: unimod mod=241.088497, formula mass=241.0884868
# MDCC@C: unimod mod=383.148121, formula mass=383.14810669999997
# Maleimide-PEO2-Biotin@C: unimod mod=525.225719, formula mass=525.2256957
# Methyl-PEO12-Maleimide@C: unimod mod=710.383719, formula mass=710.3836847
# Microcin@Protein C-term: unimod mod=831.197041, formula mass=831.1970117999999
# MicrocinC7@Protein C-term: unimod mod=386.110369, formula mass=386.1103532
# Molybdopterin@C: unimod mod=521.884073, formula mass=521.8840574000001
# MolybdopterinGD+Delta:S(-1)Se(1)@C: unimod mod=1620.930224, formula mass=1620.9301708
# MolybdopterinGD@C: unimod mod=1572.985775, formula mass=1572.9857208
# MolybdopterinGD@D: unimod mod=1572.985775, formula mass=1572.9857208
# MolybdopterinGD@U: unimod mod=1572.985775, formula mass=1572.9857208
# MurNAc@A: unimod mod=275.100502, formula mass=275.1004901
# Myristoleyl@G^Protein N-term: unimod mod=208.182715, formula mass=208.18270449999997
# Myristoyl@C: unimod mod=210.198366, formula mass=210.19835369999998
# Myristoyl@G^Any N-term: unimod mod=210.198366, formula mass=210.19835369999998
# Myristoyl@K: unimod mod=210.198366, formula mass=210.19835369999998
# NA-LNO2@C: unimod mod=325.225309, formula mass=325.2252922
# NA-LNO2@H: unimod mod=325.225309, formula mass=325.2252922
# NA-OA-NO2@C: unimod mod=327.240959, formula mass=327.2409414
# NA-OA-NO2@H: unimod mod=327.240959, formula mass=327.2409414
# NHS-LC-Biotin@Any N-term: unimod mod=339.161662, formula mass=339.1616469
# NHS-LC-Biotin@K: unimod mod=339.161662, formula mass=339.1616469
# NHS-fluorescein@K: unimod mod=471.131802, formula mass=471.1317885
# NP40@Any N-term: unimod mod=220.182715, formula mass=220.18270449999997
# NQIGG@K: unimod mod=469.228496, formula mass=469.2284737
# NeuAc@N: unimod mod=291.095417, formula mass=291.0954042
# NeuAc@S: unimod mod=291.095417, formula mass=291.0954042
# NeuAc@T: unimod mod=291.095417, formula mass=291.0954042
# NeuGc@N: unimod mod=307.090331, formula mass=307.09031830000004
# NeuGc@S: unimod mod=307.090331, formula mass=307.09031830000004
# NeuGc@T: unimod mod=307.090331, formula mass=307.09031830000004
# OxArgBiotin@R: unimod mod=310.135113, formula mass=310.1350999
# OxArgBiotinRed@R: unimod mod=312.150763, formula mass=312.1507491
# OxLysBiotin@K: unimod mod=352.156911, formula mass=352.15689549999996
# OxLysBiotinRed@K: unimod mod=354.172562, formula mass=354.17254469999995
# OxProBiotin@P: unimod mod=369.183461, formula mass=369.18344249999996
# OxProBiotinRed@P: unimod mod=371.199111, formula mass=371.1990917
# PEO-Iodoacetyl-LC-Biotin@C: unimod mod=414.193691, formula mass=414.19367129999995
# Palmitoleyl@C: unimod mod=236.214016, formula mass=236.2140029
# Palmitoleyl@S: unimod mod=236.214016, formula mass=236.2140029
# Palmitoleyl@T: unimod mod=236.214016, formula mass=236.2140029
# Palmitoyl@C: unimod mod=238.229666, formula mass=238.22965209999998
# Palmitoyl@K: unimod mod=238.229666, formula mass=238.22965209999998
# Palmitoyl@Protein N-term: unimod mod=238.229666, formula mass=238.22965209999998
# Palmitoyl@S: unimod mod=238.229666, formula mass=238.22965209999998
# Palmitoyl@T: unimod mod=238.229666, formula mass=238.22965209999998
# Pent(1)HexNAc(1)@S: unimod mod=335.121631, formula mass=335.1216167
# Pent(1)HexNAc(1)@T: unimod mod=335.121631, formula mass=335.1216167
# Pent(2)@S: unimod mod=264.084518, formula mass=264.0845064
# Pent(2)@T: unimod mod=264.084518, formula mass=264.0845064
# PhosphoCytidine@S: unimod mod=305.041287, formula mass=305.04127550000004
# PhosphoCytidine@T: unimod mod=305.041287, formula mass=305.04127550000004
# PhosphoCytidine@Y: unimod mod=305.041287, formula mass=305.04127550000004
# PhosphoHex(2)@N: unimod mod=404.071978, formula mass=404.0719619000001
# PhosphoHex(2)@S: unimod mod=404.071978, formula mass=404.0719619000001
# PhosphoHex(2)@T: unimod mod=404.071978, formula mass=404.0719619000001
# PhosphoHexNAc@S: unimod mod=283.045704, formula mass=283.0456924
# PhosphoHexNAc@T: unimod mod=283.045704, formula mass=283.0456924
# PhosphoUridine@H: unimod mod=306.025302, formula mass=306.02529180000005
# PhosphoUridine@Y: unimod mod=306.025302, formula mass=306.02529180000005
# Phosphoadenosine@H: unimod mod=329.05252, formula mass=329.0525078
# Phosphoadenosine@K: unimod mod=329.05252, formula mass=329.0525078
# Phosphoadenosine@S: unimod mod=329.05252, formula mass=329.0525078
# Phosphoadenosine@T: unimod mod=329.05252, formula mass=329.0525078
# Phosphoadenosine@Y: unimod mod=329.05252, formula mass=329.0525078
# Phosphoguanosine@H: unimod mod=345.047435, formula mass=345.0474219
# Phosphoguanosine@K: unimod mod=345.047435, formula mass=345.0474219
# Phosphopantetheine@S: unimod mod=340.085794, formula mass=340.0857796
# PhosphoribosyldephosphoCoA@S: unimod mod=881.146904, formula mass=881.1468695000001
# Phycocyanobilin@C: unimod mod=586.279135, formula mass=586.2791122
# Phycoerythrobilin@C: unimod mod=588.294785, formula mass=588.2947614000001
# Phytochromobilin@C: unimod mod=584.263485, formula mass=584.263463
# PropylNAGthiazoline@C: unimod mod=232.064354, formula mass=232.064344
# Puromycin@Any C-term: unimod mod=453.212452, formula mass=453.21243300000003
# QAT@C: unimod mod=171.149738, formula mass=171.1497279
# QEQTGG@K: unimod mod=600.250354, formula mass=600.2503263
# QQQTGG@K: unimod mod=599.266339, formula mass=599.26631
# QTGG@K: unimod mod=343.149184, formula mass=343.1491672
# RNPXL@K^Any N-term: unimod mod=324.035867, formula mass=324.0358551
# RNPXL@R^Any N-term: unimod mod=324.035867, formula mass=324.0358551
# Retinylidene@K: unimod mod=266.203451, formula mass=266.2034396
# SUMO2135@K: unimod mod=2135.920496, formula mass=2135.9203990999995
# SUMO3549@K: unimod mod=3549.536568, formula mass=3549.536408
# Sulfo-NHS-LC-LC-Biotin@Any N-term: unimod mod=452.245726, formula mass=452.2457048
# Sulfo-NHS-LC-LC-Biotin@K: unimod mod=452.245726, formula mass=452.2457048
# SulfoGMBS@C: unimod mod=458.162391, formula mass=458.1623729
# TAMRA-FP@S: unimod mod=659.312423, formula mass=659.3123978
# TAMRA-FP@Y: unimod mod=659.312423, formula mass=659.3123978
# TMPP-Ac:13C(9)@Any N-term: unimod mod=581.211328, formula mass=581.2113134
# TMPP-Ac:13C(9)@K: unimod mod=581.211328, formula mass=581.2113134
# TMPP-Ac:13C(9)@Y: unimod mod=581.211328, formula mass=581.2113134
# TMPP-Ac@Any N-term: unimod mod=572.181134, formula mass=572.1811148
# TMPP-Ac@K: unimod mod=572.181134, formula mass=572.1811148
# TMPP-Ac@Y: unimod mod=572.181134, formula mass=572.1811148
# ...
# dHex(2)Hex(1)HexNAc(1)Kdn(1)@s: unimod mod=907.316881, formula mass=907.3168420000001
# dHex(2)Hex(1)HexNAc(1)Kdn(1)@t: unimod mod=907.316881, formula mass=907.3168420000001
# dHex(2)Hex(1)HexNAc(2)Kdn(1)@s: unimod mod=1110.396254, formula mass=1110.3962055000002
# dHex(2)Hex(1)HexNAc(2)Kdn(1)@t: unimod mod=1110.396254, formula mass=1110.3962055000002
# dHex(2)Hex(1)HexNAc(2)NeuAc(1)@s: unimod mod=1151.422803, formula mass=1151.4227525000001
# dHex(2)Hex(1)HexNAc(2)NeuAc(1)@t: unimod mod=1151.422803, formula mass=1151.4227525000001
# dHex(2)Hex(1)HexNAc(2)NeuGc(1)@s: unimod mod=1167.417718, formula mass=1167.4176666
# dHex(2)Hex(1)HexNAc(2)NeuGc(1)@t: unimod mod=1167.417718, formula mass=1167.4176666
# dHex(2)Hex(1)HexNAc(3)@s: unimod mod=1063.406759, formula mass=1063.4067118
# dHex(2)Hex(1)HexNAc(3)@t: unimod mod=1063.406759, formula mass=1063.4067118
# dHex(2)Hex(1)HexNAc(4)Sulf(1)@s: unimod mod=1346.442946, formula mass=1346.4428876
# dHex(2)Hex(1)HexNAc(4)Sulf(1)@t: unimod mod=1346.442946, formula mass=1346.4428876
# dHex(2)Hex(2)@s: unimod mod=616.221465, formula mass=616.2214378000001
# dHex(2)Hex(2)@t: unimod mod=616.221465, formula mass=616.2214378000001
# dHex(2)Hex(2)HexA(1)@s: unimod mod=792.253553, formula mass=792.2535192
# dHex(2)Hex(2)HexA(1)@t: unimod mod=792.253553, formula mass=792.2535192
# dHex(2)Hex(2)HexA(1)HexNAc(1)@s: unimod mod=995.332925, formula mass=995.3328827
# dHex(2)Hex(2)HexA(1)HexNAc(1)@t: unimod mod=995.332925, formula mass=995.3328827
# dHex(2)Hex(2)HexA(1)HexNAc(2)Sulf(1)@s: unimod mod=1278.369113, formula mass=1278.3690585000002
# dHex(2)Hex(2)HexA(1)HexNAc(2)Sulf(1)@t: unimod mod=1278.369113, formula mass=1278.3690585000002
# dHex(2)Hex(2)HexNAc(1)@s: unimod mod=819.300837, formula mass=819.3008013000001
# dHex(2)Hex(2)HexNAc(1)@t: unimod mod=819.300837, formula mass=819.3008013000001
# dHex(2)Hex(2)HexNAc(2)@n: unimod mod=1022.38021, formula mass=1022.3801648000001
# dHex(2)Hex(2)HexNAc(2)@s: unimod mod=1022.38021, formula mass=1022.3801648000001
# dHex(2)Hex(2)HexNAc(2)@t: unimod mod=1022.38021, formula mass=1022.3801648000001
# dHex(2)Hex(2)HexNAc(2)Kdn(1)@s: unimod mod=1272.449077, formula mass=1272.4490220000002
# dHex(2)Hex(2)HexNAc(2)Kdn(1)@t: unimod mod=1272.449077, formula mass=1272.4490220000002
# dHex(2)Hex(2)HexNAc(2)NeuAc(1)@s: unimod mod=1313.475627, formula mass=1313.4755690000002
# dHex(2)Hex(2)HexNAc(2)NeuAc(1)@t: unimod mod=1313.475627, formula mass=1313.4755690000002
# dHex(2)Hex(2)HexNAc(2)NeuAc(1)Sulf(1)@s: unimod mod=1393.432441, formula mass=1393.4323813
# dHex(2)Hex(2)HexNAc(2)NeuAc(1)Sulf(1)@t: unimod mod=1393.432441, formula mass=1393.4323813
# dHex(2)Hex(2)HexNAc(2)NeuGc(1)@s: unimod mod=1329.470541, formula mass=1329.4704831
# dHex(2)Hex(2)HexNAc(2)NeuGc(1)@t: unimod mod=1329.470541, formula mass=1329.4704831
# dHex(2)Hex(2)HexNAc(2)Sulf(1)@s: unimod mod=1102.337025, formula mass=1102.3369771
# dHex(2)Hex(2)HexNAc(2)Sulf(1)@t: unimod mod=1102.337025, formula mass=1102.3369771
# dHex(2)Hex(2)HexNAc(2)Sulf(2)@s: unimod mod=1182.293839, formula mass=1182.2937894000002
# dHex(2)Hex(2)HexNAc(2)Sulf(2)@t: unimod mod=1182.293839, formula mass=1182.2937894000002
# dHex(2)Hex(2)HexNAc(3)@n: unimod mod=1225.459583, formula mass=1225.4595283
# dHex(2)Hex(2)HexNAc(3)@s: unimod mod=1225.459583, formula mass=1225.4595283
# dHex(2)Hex(2)HexNAc(3)@t: unimod mod=1225.459583, formula mass=1225.4595283
# dHex(2)Hex(2)HexNAc(3)NeuAc(1)@s: unimod mod=1516.554999, formula mass=1516.5549325
# dHex(2)Hex(2)HexNAc(3)NeuAc(1)@t: unimod mod=1516.554999, formula mass=1516.5549325
# dHex(2)Hex(2)HexNAc(3)NeuGc(1)@s: unimod mod=1532.549914, formula mass=1532.5498466
# dHex(2)Hex(2)HexNAc(3)NeuGc(1)@t: unimod mod=1532.549914, formula mass=1532.5498466
# dHex(2)Hex(2)HexNAc(3)Sulf(1)@s: unimod mod=1305.416397, formula mass=1305.4163406
# dHex(2)Hex(2)HexNAc(3)Sulf(1)@t: unimod mod=1305.416397, formula mass=1305.4163406
# dHex(2)Hex(2)HexNAc(4)@s: unimod mod=1428.538955, formula mass=1428.5388917999999
# dHex(2)Hex(2)HexNAc(4)@t: unimod mod=1428.538955, formula mass=1428.5388917999999
# dHex(2)Hex(2)HexNAc(4)Sulf(2)@s: unimod mod=1588.452584, formula mass=1588.4525164000001
# dHex(2)Hex(2)HexNAc(4)Sulf(2)@t: unimod mod=1588.452584, formula mass=1588.4525164000001
# dHex(2)Hex(2)HexNAc(5)@s: unimod mod=1631.618328, formula mass=1631.6182552999999
# dHex(2)Hex(2)HexNAc(5)@t: unimod mod=1631.618328, formula mass=1631.6182552999999
# dHex(2)Hex(2)HexNAc(6)Sulf(1)@s: unimod mod=1914.654515, formula mass=1914.6544311
# dHex(2)Hex(2)HexNAc(6)Sulf(1)@t: unimod mod=1914.654515, formula mass=1914.6544311
# dHex(2)Hex(3)@s: unimod mod=778.274288, formula mass=778.2742543
# dHex(2)Hex(3)@t: unimod mod=778.274288, formula mass=778.2742543
# dHex(2)Hex(3)HexA(1)HexNAc(1)Sulf(1)@s: unimod mod=1237.342563, formula mass=1237.3425115
# dHex(2)Hex(3)HexA(1)HexNAc(1)Sulf(1)@t: unimod mod=1237.342563, formula mass=1237.3425115
# dHex(2)Hex(3)HexA(1)HexNAc(2)Sulf(1)@s: unimod mod=1440.421936, formula mass=1440.4218750000002
# dHex(2)Hex(3)HexA(1)HexNAc(2)Sulf(1)@t: unimod mod=1440.421936, formula mass=1440.4218750000002
# dHex(2)Hex(3)HexA(1)HexNAc(3)Sulf(1)@s: unimod mod=1643.501309, formula mass=1643.5012385000002
# dHex(2)Hex(3)HexA(1)HexNAc(3)Sulf(1)@t: unimod mod=1643.501309, formula mass=1643.5012385000002
# dHex(2)Hex(3)HexNAc(1)Sulf(1)@s: unimod mod=1061.310475, formula mass=1061.3104301
# dHex(2)Hex(3)HexNAc(1)Sulf(1)@t: unimod mod=1061.310475, formula mass=1061.3104301
# dHex(2)Hex(3)HexNAc(2)@n: unimod mod=1184.433033, formula mass=1184.4329813
# dHex(2)Hex(3)HexNAc(2)@s: unimod mod=1184.433033, formula mass=1184.4329813
# dHex(2)Hex(3)HexNAc(2)@t: unimod mod=1184.433033, formula mass=1184.4329813
# dHex(2)Hex(3)HexNAc(2)NeuGc(1)@s: unimod mod=1491.523365, formula mass=1491.5232996
# dHex(2)Hex(3)HexNAc(2)NeuGc(1)@t: unimod mod=1491.523365, formula mass=1491.5232996
# dHex(2)Hex(3)HexNAc(2)Sulf(1)@s: unimod mod=1264.389848, formula mass=1264.3897936
# dHex(2)Hex(3)HexNAc(2)Sulf(1)@t: unimod mod=1264.389848, formula mass=1264.3897936
# dHex(2)Hex(3)HexNAc(3)@n: unimod mod=1387.512406, formula mass=1387.5123448000002
# dHex(2)Hex(3)HexNAc(3)@s: unimod mod=1387.512406, formula mass=1387.5123448000002
# dHex(2)Hex(3)HexNAc(3)@t: unimod mod=1387.512406, formula mass=1387.5123448000002
# dHex(2)Hex(3)HexNAc(3)NeuAc(1)@s: unimod mod=1678.607823, formula mass=1678.607749
# dHex(2)Hex(3)HexNAc(3)NeuAc(1)@t: unimod mod=1678.607823, formula mass=1678.607749
# dHex(2)Hex(3)HexNAc(3)NeuAc(2)@s: unimod mod=1969.703239, formula mass=1969.7031532
# dHex(2)Hex(3)HexNAc(3)NeuAc(2)@t: unimod mod=1969.703239, formula mass=1969.7031532
# dHex(2)Hex(3)HexNAc(3)Pent(1)@n: unimod mod=1519.554665, formula mass=1519.5545980000002
# dHex(2)Hex(3)HexNAc(3)Pent(2)@n: unimod mod=1651.596924, formula mass=1651.5968512
# dHex(2)Hex(3)HexNAc(3)Sulf(1)@s: unimod mod=1467.469221, formula mass=1467.4691571
# dHex(2)Hex(3)HexNAc(3)Sulf(1)@t: unimod mod=1467.469221, formula mass=1467.4691571
# dHex(2)Hex(3)HexNAc(4)@n: unimod mod=1590.591779, formula mass=1590.5917083
# dHex(2)Hex(3)HexNAc(4)@s: unimod mod=1590.591779, formula mass=1590.5917083
# dHex(2)Hex(3)HexNAc(4)@t: unimod mod=1590.591779, formula mass=1590.5917083
# dHex(2)Hex(3)HexNAc(4)NeuAc(1)@n: unimod mod=1881.687195, formula mass=1881.6871125
# dHex(2)Hex(3)HexNAc(4)Pent(1)@n: unimod mod=1722.634037, formula mass=1722.6339615
# dHex(2)Hex(3)HexNAc(4)Pent(2)@n: unimod mod=1854.676296, formula mass=1854.6762147
# dHex(2)Hex(3)HexNAc(5)@n: unimod mod=1793.671151, formula mass=1793.6710718
# dHex(2)Hex(3)HexNAc(5)@s: unimod mod=1793.671151, formula mass=1793.6710718
# dHex(2)Hex(3)HexNAc(5)@t: unimod mod=1793.671151, formula mass=1793.6710718
# dHex(2)Hex(3)HexNAc(6)@n: unimod mod=1996.750524, formula mass=1996.7504353
# dHex(2)Hex(4)@s: unimod mod=940.327112, formula mass=940.3270708
# dHex(2)Hex(4)@t: unimod mod=940.327112, formula mass=940.3270708
# dHex(2)Hex(4)HexA(1)HexNAc(3)Sulf(1)@s: unimod mod=1805.554132, formula mass=1805.5540550000003
# dHex(2)Hex(4)HexA(1)HexNAc(3)Sulf(1)@t: unimod mod=1805.554132, formula mass=1805.5540550000003
# dHex(2)Hex(4)HexNAc(1)@s: unimod mod=1143.406484, formula mass=1143.4064343
# dHex(2)Hex(4)HexNAc(1)@t: unimod mod=1143.406484, formula mass=1143.4064343
# dHex(2)Hex(4)HexNAc(2)@n: unimod mod=1346.485857, formula mass=1346.4857978
# dHex(2)Hex(4)HexNAc(2)@s: unimod mod=1346.485857, formula mass=1346.4857978
# dHex(2)Hex(4)HexNAc(2)@t: unimod mod=1346.485857, formula mass=1346.4857978
# dHex(2)Hex(4)HexNAc(3)@n: unimod mod=1549.56523, formula mass=1549.5651613
# dHex(2)Hex(4)HexNAc(3)NeuAc(1)Sulf(1)@n: unimod mod=1920.617461, formula mass=1920.6173778
# dHex(2)Hex(4)HexNAc(3)Pent(1)@n: unimod mod=1681.607488, formula mass=1681.6074145000002
# dHex(2)Hex(4)HexNAc(4)@n: unimod mod=1752.644602, formula mass=1752.6445248
# dHex(2)Hex(4)HexNAc(4)@s: unimod mod=1752.644602, formula mass=1752.6445248
# dHex(2)Hex(4)HexNAc(4)@t: unimod mod=1752.644602, formula mass=1752.6445248
# dHex(2)Hex(4)HexNAc(4)Pent(1)@n: unimod mod=1884.686861, formula mass=1884.6867780000002
# dHex(2)Hex(4)HexNAc(4)Sulf(1)@n: unimod mod=1832.601417, formula mass=1832.6013371000001
# dHex(2)Hex(4)HexNAc(5)@n: unimod mod=1955.723975, formula mass=1955.7238883
# dHex(2)Hex(4)HexNAc(5)@s: unimod mod=1955.723975, formula mass=1955.7238883
# dHex(2)Hex(4)HexNAc(5)@t: unimod mod=1955.723975, formula mass=1955.7238883
# dHex(2)Hex(5)HexNAc(2)Me(1)@s: unimod mod=1522.554331, formula mass=1522.5542635000002
# dHex(2)Hex(5)HexNAc(2)Me(1)@t: unimod mod=1522.554331, formula mass=1522.5542635000002
# dHex(2)Hex(5)HexNAc(3)Pent(1)@n: unimod mod=1843.660312, formula mass=1843.6602310000003
# dHex(2)Hex(5)HexNAc(4)@n: unimod mod=1914.697426, formula mass=1914.6973413
# dHex(2)HexNAc(2)Kdn(1)@s: unimod mod=948.34343, formula mass=948.3433890000001
# dHex(2)HexNAc(2)Kdn(1)@t: unimod mod=948.34343, formula mass=948.3433890000001
# dHex(2)HexNAc(5)@s: unimod mod=1307.512681, formula mass=1307.5126223
# dHex(2)HexNAc(5)@t: unimod mod=1307.512681, formula mass=1307.5126223
# dHex(2)HexNAc(7)@s: unimod mod=1713.671426, formula mass=1713.6713492999997
# dHex(2)HexNAc(7)@t: unimod mod=1713.671426, formula mass=1713.6713492999997
# dHex(3)Hex(1)HexNAc(2)Kdn(1)@s: unimod mod=1256.454163, formula mass=1256.4541079
# dHex(3)Hex(1)HexNAc(2)Kdn(1)@t: unimod mod=1256.454163, formula mass=1256.4541079
# dHex(3)Hex(1)HexNAc(3)Kdn(1)@s: unimod mod=1459.533535, formula mass=1459.5334714
# dHex(3)Hex(1)HexNAc(3)Kdn(1)@t: unimod mod=1459.533535, formula mass=1459.5334714
# dHex(3)Hex(2)HexA(1)HexNAc(2)Sulf(1)@s: unimod mod=1424.427021, formula mass=1424.4269609
# dHex(3)Hex(2)HexA(1)HexNAc(2)Sulf(1)@t: unimod mod=1424.427021, formula mass=1424.4269609
# dHex(3)Hex(2)HexNAc(2)@s: unimod mod=1168.438119, formula mass=1168.4380672
# dHex(3)Hex(2)HexNAc(2)@t: unimod mod=1168.438119, formula mass=1168.4380672
# dHex(3)Hex(2)HexNAc(2)Kdn(1)@s: unimod mod=1418.506986, formula mass=1418.5069244000001
# dHex(3)Hex(2)HexNAc(2)Kdn(1)@t: unimod mod=1418.506986, formula mass=1418.5069244000001
# dHex(3)Hex(2)HexNAc(3)@s: unimod mod=1371.517491, formula mass=1371.5174307000002
# dHex(3)Hex(2)HexNAc(3)@t: unimod mod=1371.517491, formula mass=1371.5174307000002
# dHex(3)Hex(2)HexNAc(3)Kdn(1)@s: unimod mod=1621.586359, formula mass=1621.5862879000001
# dHex(3)Hex(2)HexNAc(3)Kdn(1)@t: unimod mod=1621.586359, formula mass=1621.5862879000001
# dHex(3)Hex(2)HexNAc(4)@s: unimod mod=1574.596864, formula mass=1574.5967942
# dHex(3)Hex(2)HexNAc(4)@t: unimod mod=1574.596864, formula mass=1574.5967942
# dHex(3)Hex(2)HexNAc(4)Sulf(2)@s: unimod mod=1734.510493, formula mass=1734.5104188
# dHex(3)Hex(2)HexNAc(4)Sulf(2)@t: unimod mod=1734.510493, formula mass=1734.5104188
# dHex(3)Hex(3)HexNAc(1)@s: unimod mod=1127.41157, formula mass=1127.4115202
# dHex(3)Hex(3)HexNAc(1)@t: unimod mod=1127.41157, formula mass=1127.4115202
# dHex(3)Hex(3)HexNAc(2)@s: unimod mod=1330.490942, formula mass=1330.4908837
# dHex(3)Hex(3)HexNAc(2)@t: unimod mod=1330.490942, formula mass=1330.4908837
# dHex(3)Hex(3)HexNAc(3)@s: unimod mod=1533.570315, formula mass=1533.5702471999998
# dHex(3)Hex(3)HexNAc(3)@t: unimod mod=1533.570315, formula mass=1533.5702471999998
# dHex(3)Hex(3)HexNAc(3)NeuAc(1)@s: unimod mod=1824.665732, formula mass=1824.6656514000001
# dHex(3)Hex(3)HexNAc(3)NeuAc(1)@t: unimod mod=1824.665732, formula mass=1824.6656514000001
# dHex(3)Hex(3)HexNAc(3)Pent(1)@n: unimod mod=1665.612574, formula mass=1665.6125004
# dHex(3)Hex(3)HexNAc(4)@n: unimod mod=1736.649688, formula mass=1736.6496107
# dHex(3)Hex(3)HexNAc(4)Pent(1)@n: unimod mod=1868.691946, formula mass=1868.6918639
# dHex(3)Hex(4)HexNAc(4)@n: unimod mod=1898.702511, formula mass=1898.7024271999999
# dHex(3)Hex(4)HexNAc(4)@s: unimod mod=1898.702511, formula mass=1898.7024271999999
# dHex(3)Hex(4)HexNAc(4)@t: unimod mod=1898.702511, formula mass=1898.7024271999999
# dHex(3)Hex(4)HexNAc(4)Sulf(1)@n: unimod mod=1978.659326, formula mass=1978.6592395
# dHex(3)HexNAc(3)Kdn(1)@s: unimod mod=1297.480712, formula mass=1297.4806549
# dHex(3)HexNAc(3)Kdn(1)@t: unimod mod=1297.480712, formula mass=1297.4806549
# dHex(4)Hex(1)HexNAc(1)Kdn(2)@s: unimod mod=1449.501567, formula mass=1449.501504
# dHex(4)Hex(1)HexNAc(1)Kdn(2)@t: unimod mod=1449.501567, formula mass=1449.501504
# dHex(4)Hex(1)HexNAc(2)Kdn(1)@s: unimod mod=1402.512072, formula mass=1402.5120103
# dHex(4)Hex(1)HexNAc(2)Kdn(1)@t: unimod mod=1402.512072, formula mass=1402.5120103
# dHex(4)Hex(1)HexNAc(3)Kdn(1)@s: unimod mod=1605.591444, formula mass=1605.5913738000002
# dHex(4)Hex(1)HexNAc(3)Kdn(1)@t: unimod mod=1605.591444, formula mass=1605.5913738000002
# dHex(4)Hex(2)HexNAc(2)Kdn(1)@s: unimod mod=1564.564895, formula mass=1564.5648268
# dHex(4)Hex(2)HexNAc(2)Kdn(1)@t: unimod mod=1564.564895, formula mass=1564.5648268
# dHex(4)Hex(2)HexNAc(3)@s: unimod mod=1517.5754, formula mass=1517.5753331
# dHex(4)Hex(2)HexNAc(3)@t: unimod mod=1517.5754, formula mass=1517.5753331
# dHex(4)Hex(3)HexNAc(2)NeuAc(1)@s: unimod mod=1767.644268, formula mass=1767.6441903
# dHex(4)Hex(3)HexNAc(2)NeuAc(1)@t: unimod mod=1767.644268, formula mass=1767.6441903
# dHex(4)Hex(3)HexNAc(3)@s: unimod mod=1679.628224, formula mass=1679.6281496000001
# dHex(4)Hex(3)HexNAc(3)@t: unimod mod=1679.628224, formula mass=1679.6281496000001
# dHex(4)HexNAc(3)Kdn(1)@s: unimod mod=1443.538621, formula mass=1443.5385573
# dHex(4)HexNAc(3)Kdn(1)@t: unimod mod=1443.538621, formula mass=1443.5385573
# iTRAQ8plex:13C(6)15N(2)@c: unimod mod=304.19904, formula mass=304.1990291
# iTRAQ8plex:13C(6)15N(2)@k: unimod mod=304.19904, formula mass=304.1990291
# iTRAQ8plex:13C(6)15N(2)@y: unimod mod=304.19904, formula mass=304.1990291
# iTRAQ8plex@c: unimod mod=304.20536, formula mass=304.2053489
# iTRAQ8plex@h: unimod mod=304.20536, formula mass=304.2053489
# iTRAQ8plex@k: unimod mod=304.20536, formula mass=304.2053489
# iTRAQ8plex@s: unimod mod=304.20536, formula mass=304.2053489
# iTRAQ8plex@t: unimod mod=304.20536, formula mass=304.2053489
# iTRAQ8plex@y: unimod mod=304.20536, formula mass=304.2053489
# iodoTMT6plex@c: unimod mod=329.226595, formula mass=329.22658110000003
# iodoTMT6plex@d: unimod mod=329.226595, formula mass=329.22658110000003
# iodoTMT6plex@e: unimod mod=329.226595, formula mass=329.22658110000003
# iodoTMT6plex@h: unimod mod=329.226595, formula mass=329.22658110000003
# iodoTMT6plex@k: unimod mod=329.226595, formula mass=329.22658110000003
# iodoTMT@c: unimod mod=324.216141, formula mass=324.2161239
# iodoTMT@d: unimod mod=324.216141, formula mass=324.2161239
# iodoTMT@e: unimod mod=324.216141, formula mass=324.2161239
# iodoTMT@h: unimod mod=324.216141, formula mass=324.2161239
# iodoTMT@k: unimod mod=324.216141, formula mass=324.2161239
# maleimide3@c: unimod mod=969.366232, formula mass=969.3661881
# maleimide3@k: unimod mod=969.366232, formula mass=969.3661881
# maleimide5@c: unimod mod=1293.471879, formula mass=1293.4718211
# maleimide5@k: unimod mod=1293.471879, formula mass=1293.4718211
# probiotinhydrazide@p: unimod mod=258.115047, formula mass=258.1150338
# pupylation@k: unimod mod=243.085521, formula mass=243.0855099
# s-GlcNAc@s: unimod mod=283.036187, formula mass=283.03617579999997
# s-GlcNAc@t: unimod mod=283.036187, formula mass=283.03617579999997
# spermine@q: unimod mod=185.189198, formula mass=185.18918539999999

# %%
#export

def get_modification_mass(
    peplen:int, 
    mod_names:list, 
    mod_sites:Union[list, np.array]
):
    masses = np.zeros(peplen)
    for site, mod in zip(mod_sites, mod_names):
        if site == 0:
            masses[site] += MOD_MASS[mod]
        elif site == -1:
            masses[site] += MOD_MASS[mod]
        else:
            masses[site-1] += MOD_MASS[mod]
    return masses

# %%
seq = 'AGHCEWQMK'
mod_names = ['Acetyl@Protein N-term', 'Carbamidomethyl@C', 'Oxidation@M']
mod_sites = [0, 4, 8]

get_modification_mass(len(seq), mod_names, mod_sites)
# Out:
# array([42.0105633,  0.       ,  0.       , 57.0214611,  0.       ,
#         0.       ,  0.       , 15.9949141,  0.       ])

# %%
# %timeit get_modification_mass(len(seq), mod_names, mod_sites)
# Out:
# 2.06 µs ± 93.5 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
#export
@numba.jit(nopython=True, nogil=True)
def _get_modloss(mod_losses, _loss_importance):
    prev_importance = _loss_importance[0]
    prev_most = 0
    for i, _curr_imp in enumerate(_loss_importance[1:]):
        if _curr_imp > prev_importance:
            prev_most = i+1
            prev_importance = _curr_imp
        else:
            mod_losses[i+1] = mod_losses[prev_most]
    return mod_losses

def get_modloss_mass(
    peplen: int, 
    mod_names: list, 
    mod_sites: Union[list, np.array],
    for_nterm_frag: bool,
):
    if not mod_names: return np.zeros(peplen-1)
    mod_losses = np.zeros(peplen+2)
    mod_losses[mod_sites] = [MOD_LOSS_MASS[mod] for mod in mod_names]
    _loss_importance = np.zeros(peplen+2)
    _loss_importance[mod_sites] = [
        MOD_LOSS_IMPORTANCE[mod] if mod in MOD_LOSS_IMPORTANCE else 0 
        for mod in mod_names
    ]
    
    # Will not consider the modloss if the corresponding modloss_importance is 0
    mod_losses[_loss_importance==0] = 0

    if for_nterm_frag:
        return _get_modloss(mod_losses, _loss_importance)[1:-2]
    else:
        return _get_modloss(mod_losses[::-1], _loss_importance[::-1])[-3:0:-1]

# %%
mod_names = ['Oxidation@M', 'Phospho@S', 'Carbamidomethyl@C']
mod_sites = [0, 4, 8]
MOD_LOSS_IMPORTANCE['Oxidation@M'] = 10
get_modloss_mass(10, mod_names, mod_sites, True)
# Out:
# array([63.9982825, 63.9982825, 63.9982825, 97.9768922, 97.9768922,
#        97.9768922, 97.9768922, 97.9768922, 97.9768922])

# %%
MOD_LOSS_IMPORTANCE['Oxidation@M'] = 0
get_modloss_mass(10, mod_names, mod_sites, True)
# Out:
# array([ 0.       ,  0.       ,  0.       , 97.9768922, 97.9768922,
#        97.9768922, 97.9768922, 97.9768922, 97.9768922])

# %%
MOD_LOSS_IMPORTANCE['Oxidation@M'] = 10
get_modloss_mass(10, mod_names, mod_sites, False)
# Out:
# array([97.9768922, 97.9768922, 97.9768922,  0.       ,  0.       ,
#         0.       ,  0.       ,  0.       ,  0.       ])

# %% [markdown]
# ### Note that get_modloss_mass is a little bit time comsuming
# `%timeit get_modloss_mass(10, mod_names, mod_sites, False)`
#
# `Results (12 seconds in total): 12.6 µs ± 96.4 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)`
