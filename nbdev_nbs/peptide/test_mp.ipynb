# %%
import pandas as pd
repeat = 100
peptides = ['AGHCEWQMKAADER']*repeat
mods = ['Acetyl@Protein N-term;Carbamidomethyl@C;Oxidation@M']*repeat
sites = ['0;4;8']*repeat
peptides += ['AGHCEWQMK']*repeat
mods += ['']*repeat
sites += ['']*repeat

precursor_df = pd.DataFrame({
    'sequence': peptides,
    'mods': mods,
    'mod_sites': sites
})
precursor_df['nAA'] = precursor_df['sequence'].str.len()
precursor_df['charge'] = 2

# %%
from alphabase.peptide.precursor import calc_precursor_isotope_mp

precursor_df = calc_precursor_isotope_mp(precursor_df, processes=2, mp_batch_size=50)
precursor_df
# Out:
#            sequence                                               mods  \
# 100       AGHCEWQMK
# 101       AGHCEWQMK
# 102       AGHCEWQMK
# 103       AGHCEWQMK
# 104       AGHCEWQMK
# ..              ...                                                ...
# 95   AGHCEWQMKAADER  Acetyl@Protein N-term;Carbamidomethyl@C;Oxidat...
# 96   AGHCEWQMKAADER  Acetyl@Protein N-term;Carbamidomethyl@C;Oxidat...
# 97   AGHCEWQMKAADER  Acetyl@Protein N-term;Carbamidomethyl@C;Oxidat...
# 98   AGHCEWQMKAADER  Acetyl@Protein N-term;Carbamidomethyl@C;Oxidat...
# 99   AGHCEWQMKAADER  Acetyl@Protein N-term;Carbamidomethyl@C;Oxidat...
#
#     mod_sites  nAA  charge  precursor_mz  isotope_intensity_m1  \
# 100              9       2    545.233862              0.576623
# 101              9       2    545.233862              0.576623
# 102              9       2    545.233862              0.576623
# 103              9       2    545.233862              0.576623
# 104              9       2    545.233862              0.576623
# ..        ...  ...     ...           ...                   ...
# 95      0;4;8   14       2    873.869771              0.888952
# 96      0;4;8   14       2    873.869771              0.888952
# 97      0;4;8   14       2    873.869771              0.888952
# 98      0;4;8   14       2    873.869771              0.888952
# 99      0;4;8   14       2    873.869771              0.888952
#
#      isotope_intensity_m2  isotope_apex_intensity  isotope_apex_index  \
# 100              0.277542                     1.0                   0
# 101              0.277542                     1.0                   0
# 102              0.277542                     1.0                   0
# 103              0.277542                     1.0                   0
# 104              0.277542                     1.0                   0
# ..                    ...                     ...                 ...
# 95               0.529550                     1.0                   0
# 96               0.529550                     1.0                   0
# 97               0.529550                     1.0                   0
# 98               0.529550                     1.0                   0
# 99               0.529550                     1.0                   0
#
#      isotope_mz_m1  isotope_mz_m2  isotope_apex_mz
# 100     545.735512     546.237162       545.233862
# 101     545.735512     546.237162       545.233862
# 102     545.735512     546.237162       545.233862
# 103     545.735512     546.237162       545.233862
# 104     545.735512     546.237162       545.233862
# ..             ...            ...              ...
# 95      874.371421     874.873071       873.869771
# 96      874.371421     874.873071       873.869771
# 97      874.371421     874.873071       873.869771
# 98      874.371421     874.873071       873.869771
# 99      874.371421     874.873071       873.869771
#
# [200 rows x 13 columns]

# %%
import numpy as np
assert np.allclose((precursor_df.isotope_mz_m1-precursor_df.precursor_mz)*precursor_df.charge, 1.0033)
