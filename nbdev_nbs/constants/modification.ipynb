# %%
#default_exp constants.modification

# %%
# hide
import alphabase.constants.modification
__file__ = alphabase.constants.modification.__file__

# %% [markdown]
# # Modification processing
#
# The default modifications are stored in `alphabase/constants/used_mod.yaml`. Please check it to add more modifications.
#
# First, we load `alphabase/constants/used_mod.yaml` into `MOD_INFO_DICT`.
#
# Then, we extract information of `MOD_CHEM` (dict), `MOD_MASS` (dict), and `MOD_LOSS_MASS` (dict) from `MOD_INFO_DICT`. This step is done in `_update_all_by_MOD_INFO_DICT()`.
#
# At last, we convert `MOD_INFO_DICT` into a dataframe (table) named `MOD_DF` to manipulate the modifications.
#
# All these steps are done by `load_mod_yaml()`.
#
# We also provide a function `update_all_by_MOD_DF()` to update all above information from `MOD_DF`. For example, we can remove some modifications from `MOD_DF` and then `update_all_by_MOD_DF()`.

# %%
#export
import os
import numba
import numpy as np
import pandas as pd
from typing import Union, List
from copy import deepcopy

from alphabase.yaml_utils import load_yaml
from alphabase.constants.element import (
    calc_mass_from_formula, parse_formula,
)

_base_dir = os.path.dirname(__file__)

#: Dict loaded from used_mod.yaml.
# Note that we also added a "lower_case_AA" bool item  
# for more advanced usages.
MOD_INFO_DICT:dict = {}
#: Modification to formula str dict. {mod_name: formula str ('H(1)C(2)O(3)')}
MOD_CHEM:dict = {}
#: Modification to mass dict.
MOD_MASS:dict = {}
#: Modification to modification neutral loss dict.
MOD_LOSS_MASS:dict = {}
#: pd.DataFrame structure of MOD_INFO_DICT. 
MOD_DF:pd.DataFrame = pd.DataFrame()
#: Modification to formula dict of dict. {modname: {'C': n, 'H': m, ...}}
MOD_formula:dict = {}

def _update_all_by_MOD_INFO_DICT():
    global MOD_CHEM
    global MOD_MASS
    global MOD_LOSS_MASS
    global MOD_formula

    MOD_CHEM = {}
    MOD_MASS = {}
    MOD_LOSS_MASS = {}
    for mod, val in MOD_INFO_DICT.items():
        MOD_CHEM[mod] = val['composition']
        MOD_MASS[mod] = val['mass']
        MOD_formula[mod] = dict(parse_formula(val['composition']))
        MOD_LOSS_MASS[mod] = val['modloss']

def load_mod_yaml(yaml_file:str):
    """Load and init all global modification variables from a yaml file. 

    Args:
        yaml_file (str): such as `used_mod.yaml` in _base_dir_
    """
    global MOD_INFO_DICT
    global MOD_DF
    MOD_INFO_DICT = load_yaml(yaml_file)

    for mod, val in MOD_INFO_DICT.items():
        MOD_INFO_DICT[mod]['unimod_mass'] = MOD_INFO_DICT[mod]['mono_mass']
        MOD_INFO_DICT[mod]['unimod_modloss'] = MOD_INFO_DICT[mod]['modloss']
        MOD_INFO_DICT[mod]['mass'] = calc_mass_from_formula(val['composition'])
        MOD_INFO_DICT[mod]['modloss'] = calc_mass_from_formula(val['modloss_composition'])
        MOD_INFO_DICT[mod]['modloss_importance'] = 0

    _update_all_by_MOD_INFO_DICT()

    MOD_DF = pd.DataFrame().from_dict(MOD_INFO_DICT, orient='index')
    MOD_DF['name'] = MOD_DF.index

load_mod_yaml(
    os.path.join(_base_dir,
    'used_mod.yaml')
)

def load_modloss_importance(yaml_file):
    global MOD_LOSS_IMPORTANCE
    MOD_LOSS_IMPORTANCE = load_yaml(yaml_file)
    for mod,val in MOD_LOSS_IMPORTANCE.items():
        MOD_INFO_DICT[mod]['modloss_importance'] = val
    MOD_DF['modloss_importance'] = pd.DataFrame().from_dict(
        MOD_LOSS_IMPORTANCE, orient='index'
    )
    MOD_DF.loc[pd.isna(MOD_DF['modloss_importance']), 'modloss_importance'] = 0


load_modloss_importance(
    os.path.join(_base_dir,
    'modloss_importance.yaml')
)

def update_all_by_MOD_DF():
    """
    As DataFrame is more conveneint in data operation, 
    we can also process MOD_DF and then update all global 
    modification variables from MOD_DF
    """
    global MOD_INFO_DICT
    MOD_INFO_DICT = MOD_DF.to_dict(orient='index')
    _update_all_by_MOD_INFO_DICT()

def add_modifications_for_lower_case_AA():
    """ Add modifications for lower-case AAs for advanced usages """
    global MOD_DF
    lower_case_df = MOD_DF.copy()
    
    def _mod_lower_case(modname):
        modname, site = modname.split('@')
        if len(site) == 1:
            return modname+'@'+site.lower()
        elif '^' in site:
            site = site[0].lower()+site[1:]
            return modname+'@'+site
        else:
            return ''
    lower_case_df['name'] = lower_case_df['name'].apply(_mod_lower_case)
    lower_case_df = lower_case_df[lower_case_df['name']!='']
    lower_case_df.set_index('name', drop=False, inplace=True)
    lower_case_df['lower_case_AA'] = True
    MOD_DF['lower_case_AA'] = False
    MOD_DF = pd.concat([MOD_DF, lower_case_df])
    update_all_by_MOD_DF()

# %%
MOD_DF
# Out:
#                                    avge_mass        classification  \
# GlyGly@K                          114.042927    Post-translational
# 15N-oxobutanoic@C^Any N-term      -18.023900              Artefact
# 15N-oxobutanoic@S^Protein N-term  -18.023900    Post-translational
# 15N-oxobutanoic@T^Protein N-term  -18.023900    Post-translational
# 2-dimethylsuccinyl@C              144.125300   Chemical derivative
# ...                                      ...                   ...
# spermidine@Q                      128.215300   Chemical derivative
# spermine@Q                        185.309700   Chemical derivative
# sulfo+amino@Y                      95.077800   Chemical derivative
# thioacylPA@K                      159.206200   Chemical derivative
# trifluoro@L                        53.971400  Non-standard residue
#
#                                            composition     modloss  \
# GlyGly@K                              H(6)C(4)N(2)O(2)  114.042927
# 15N-oxobutanoic@C^Any N-term              H(-3)15N(-1)    0.000000
# 15N-oxobutanoic@S^Protein N-term          H(-3)15N(-1)    0.000000
# 15N-oxobutanoic@T^Protein N-term          H(-3)15N(-1)    0.000000
# 2-dimethylsuccinyl@C                      H(8)C(6)O(4)    0.000000
# ...                                                ...         ...
# spermidine@Q                             H(16)C(7)N(2)    0.000000
# spermine@Q                              H(23)C(10)N(3)    0.000000
# sulfo+amino@Y                         H(1)N(1)O(3)S(1)    0.000000
# thioacylPA@K                      H(9)C(6)N(1)O(2)S(1)    0.000000
# trifluoro@L                                  H(-3)F(3)    0.000000
#
#                                  modloss_composition   mono_mass  unimod_id  \
# GlyGly@K                            H(6)C(4)N(2)O(2)  114.042927         -1
# 15N-oxobutanoic@C^Any N-term                          -18.023584       1419
# 15N-oxobutanoic@S^Protein N-term                      -18.023584       1419
# 15N-oxobutanoic@T^Protein N-term                      -18.023584       1419
# 2-dimethylsuccinyl@C                                  144.042259       1262
# ...                                              ...         ...        ...
# spermidine@Q                                          128.131349       1421
# spermine@Q                                            185.189198       1420
# sulfo+amino@Y                                          94.967714        997
# thioacylPA@K                                          159.035399        967
# trifluoro@L                                            53.971735        750
#
#                                   unimod_mass  unimod_modloss        mass  \
# GlyGly@K                           114.042927      114.042927  114.042927
# 15N-oxobutanoic@C^Any N-term       -18.023584        0.000000  -18.023584
# 15N-oxobutanoic@S^Protein N-term   -18.023584        0.000000  -18.023584
# 15N-oxobutanoic@T^Protein N-term   -18.023584        0.000000  -18.023584
# 2-dimethylsuccinyl@C               144.042259        0.000000  144.042259
# ...                                       ...             ...         ...
# spermidine@Q                       128.131349        0.000000  128.131349
# spermine@Q                         185.189198        0.000000  185.189198
# sulfo+amino@Y                       94.967714        0.000000   94.967714
# thioacylPA@K                       159.035399        0.000000  159.035400
# trifluoro@L                         53.971735        0.000000   53.971734
#
#                                  modloss_importance  \
# GlyGly@K                                        1e6
# 15N-oxobutanoic@C^Any N-term                      0
# 15N-oxobutanoic@S^Protein N-term                  0
# 15N-oxobutanoic@T^Protein N-term                  0
# 2-dimethylsuccinyl@C                              0
# ...                                             ...
# spermidine@Q                                      0
# spermine@Q                                        0
# sulfo+amino@Y                                     0
# thioacylPA@K                                      0
# trifluoro@L                                       0
#
#                                                               name
# GlyGly@K                                                  GlyGly@K
# 15N-oxobutanoic@C^Any N-term          15N-oxobutanoic@C^Any N-term
# 15N-oxobutanoic@S^Protein N-term  15N-oxobutanoic@S^Protein N-term
# 15N-oxobutanoic@T^Protein N-term  15N-oxobutanoic@T^Protein N-term
# 2-dimethylsuccinyl@C                          2-dimethylsuccinyl@C
# ...                                                            ...
# spermidine@Q                                          spermidine@Q
# spermine@Q                                              spermine@Q
# sulfo+amino@Y                                        sulfo+amino@Y
# thioacylPA@K                                          thioacylPA@K
# trifluoro@L                                            trifluoro@L
#
# [2685 rows x 12 columns]

# %% [markdown]
# ### With NIST elements, all calculated masses are the same as unimod_mass now.

# %%
#hide
for mod, unimod_mass, mass in MOD_DF[['name','unimod_mass','mass']].values:
    if abs(unimod_mass-mass) > 1e-5:
        print(f"{mod}: unimod mod={unimod_mass}, formula mass={mass}")
# Out:
# Delta:Hg(1)@C: unimod mod=201.970617, formula mass=201.9706434

# %% [markdown]
# # Mod site representation
# * `site=0` refers to an N-term modification
# * `site=-1` refers to a C-term modification
# * `1<=site<=peplen` refers to a normal modification
#
# For example: \_0A1B2C3D4E5F6G7H8I9J10K11\_-1

# %% [markdown]
# `calc_modification_mass()` and `calc_modification_mass_sum()` are base functions to calculate masses. But for large sets of peptides, we recommend to use `calc_mod_masses_for_same_len_seqs()` instead of `calc_modification_mass()`.

# %%
#export
def calc_modification_mass(
    nAA:int, 
    mod_names:List[str], 
    mod_sites:List[int]
)->np.array:
    '''
    Calculate modification masses for the given peptide length (`nAA`), 
    and modified site list.
    Args:
        nAA (int): Peptide length
        mod_names (List[str]): Modification name list
        mod_sites (List[int]): 
            Modification site list corresponding to `mod_names`.
            * `site=0` refers to an N-term modification
            * `site=-1` refers to a C-term modification
            * `1<=site<=peplen` refers to a normal modification
    Returns:
        np.array: 1-D array with length=`nAA`. 
            Masses of modifications through the peptide, 
            `0` if sites has no modifications
    '''
    masses = np.zeros(nAA)
    for site, mod in zip(mod_sites, mod_names):
        if site == 0:
            masses[site] += MOD_MASS[mod]
        elif site == -1:
            masses[site] += MOD_MASS[mod]
        else:
            masses[site-1] += MOD_MASS[mod]
    return masses

def calc_mod_masses_for_same_len_seqs(
    nAA:int, 
    mod_names_list:List[List[str]], 
    mod_sites_list:List[List[int]]
)->np.array:
    '''
    Calculate modification masses for the given peptides with same peptide length (`nAA`).
    Args:
        nAA (int): Peptide length
        mod_names_list (List[List[str]]): 
            List (pep_count) of modification list (n_mod on each peptide)
        mod_sites_list (List[List[int]]): 
            List of modification site list corresponding to `mod_names_list`.
            * `site=0` refers to an N-term modification
            * `site=-1` refers to a C-term modification
            * `1<=site<=peplen` refers to a normal modification
    Returns:
        np.array: 
            2-D array with shape=`(nAA, pep_count or len(mod_names_list)))`. 
            Masses of modifications through all the peptides, 
            `0` if sites without modifications.
    '''
    masses = np.zeros((len(mod_names_list),nAA))
    for i, (mod_names, mod_sites) in enumerate(
        zip(mod_names_list, mod_sites_list)
    ):
        for mod, site in zip(mod_names, mod_sites): 
            if site == 0:
                masses[i,site] += MOD_MASS[mod]
            elif site == -1:
                masses[i,site] += MOD_MASS[mod]
            else:
                masses[i,site-1] += MOD_MASS[mod]
    return masses

def calc_modification_mass_sum(
    mod_names:List[str]
)->float:
    """
    Calculate summed mass of the given modification 
    without knowing the sites and peptide length.
    It is useful to calculate peptide mass.
    Args:
        mod_names (List[str]): Modification name list
    Returns:
        float: Total mass
    """
    return np.sum([
        MOD_MASS[mod] for mod in mod_names
    ])

# %%
#hide
seq = 'AGHCEWQMK'
mod_names = ['Acetyl@Protein N-term', 'Carbamidomethyl@C', 'Oxidation@M']
mod_sites = [0, 4, 8]

assert np.allclose(
    calc_modification_mass(len(seq), mod_names, mod_sites),
    [42.01056468, 0, 0, 57.02146372, 0, 0, 0, 15.99491462, 0]
)

# %%
#export
@numba.jit(nopython=True, nogil=True)
def _calc_modloss_with_importance(
    mod_losses: np.array, 
    _loss_importance: np.array
)->np.array:
    '''
    Calculate modification loss masses (e.g. -98 Da for Phospho@S/T). 
    Modification with higher `_loss_importance` has higher priorities. 
    For example, `AM(Oxidation@M)S(Phospho@S)...`,
    importance of Phospho@S > importance of Oxidation@M, so the modloss of 
    b3 ion will be -98 Da, not -64 Da.
    Args:
        mod_losses (np.array): 
            Mod loss masses of each AA position
        _loss_importance (np.array): 
            Mod loss importance of each AA position
    Returns:
        np.array: 
            New mod_loss masses selected by `_loss_importance`
    '''
    prev_importance = _loss_importance[0]
    prev_most = 0
    for i, _curr_imp in enumerate(_loss_importance[1:],1):
        if _curr_imp > prev_importance:
            prev_most = i
            prev_importance = _curr_imp
        else:
            mod_losses[i] = mod_losses[prev_most]
    return mod_losses

def calc_modloss_mass_with_importance(
    nAA: int, 
    mod_names: List, 
    mod_sites: List,
    for_nterm_frag: bool,
)->np.array:
    '''
    Calculate modification loss masses (e.g. -98 Da for Phospho@S/T, 
    -64 Da for Oxidation@M). Modifications with higher `MOD_LOSS_IMPORTANCE` 
    have higher priorities. For example, `AM(Oxidation@M)S(Phospho@S)...`,
    importance of Phospho@S > importance of Oxidation@M, so the modloss of 
    b3 ion will be -98 Da, not -64 Da.
    Args:
        nAA (int): Peptide length
        mod_names (List[str]): Modification name list
        mod_sites (List[int]): Modification site list  
        for_nterm_frag (bool):
            If `True`, the loss will be on the 
            N-term fragments (mainly `b` ions); 
            If `False`, the loss will be on the 
            C-term fragments (mainly `y` ions)
    Returns:
        np.array: mod_loss masses
    '''
    if not mod_names: return np.zeros(nAA-1)
    mod_losses = np.zeros(nAA+2)
    mod_losses[mod_sites] = [MOD_LOSS_MASS[mod] for mod in mod_names]
    _loss_importance = np.zeros(nAA+2)
    _loss_importance[mod_sites] = [
        MOD_LOSS_IMPORTANCE[mod] if mod in MOD_LOSS_IMPORTANCE else 0 
        for mod in mod_names
    ]
    
    # Will not consider the modloss if the corresponding modloss_importance is 0
    mod_losses[_loss_importance==0] = 0

    if for_nterm_frag:
        return _calc_modloss_with_importance(mod_losses, _loss_importance)[1:-2]
    else:
        return _calc_modloss_with_importance(mod_losses[::-1], _loss_importance[::-1])[-3:0:-1]

@numba.njit
def _calc_modloss(
    mod_losses: np.array
)->np.array:
    '''
    Calculate modification loss masses (e.g. -98 Da for Phospho@S/T). 
    Args:
        mod_losses (np.array): Mod loss masses of each AA position
    Returns:
        np.array: New mod_loss masses 
    '''
    for i, _curr_loss in enumerate(mod_losses[1:],1):
        if _curr_loss == 0:
            mod_losses[i] = mod_losses[i-1]
        else:
            mod_losses[i] = _curr_loss
    return mod_losses
    
def calc_modloss_mass(
    nAA: int, 
    mod_names: List, 
    mod_sites: List,
    for_nterm_frag: bool,
)->np.array:
    '''
    Calculate modification loss masses (e.g. -98 Da for Phospho@S/T, 
    -64 Da for Oxidation@M). Modifications with higher `MOD_LOSS_IMPORTANCE` 
    have higher priorities. For example, `AM(Oxidation@M)S(Phospho@S)...`,
    importance of Phospho@S > importance of Oxidation@M, so the modloss of 
    b3 ion will be -98 Da, not -64 Da.
    Args:
        nAA (int): Peptide length
        mod_names (List[str]): Modification name list
        mod_sites (List[int]): Modification site list corresponding 
        for_nterm_frag (bool): 
            If `True`, the loss will be on the 
            N-term fragments (mainly `b` ions); 
            If `False`, the loss will be on the 
            C-term fragments (mainly `y` ions)
    Returns:
        np.array: mod_loss masses
    '''
    if len(mod_names) == 0: return np.zeros(nAA-1)
    mod_losses = np.zeros(nAA+2)
    mod_losses[mod_sites] = [MOD_LOSS_MASS[mod] for mod in mod_names]

    if for_nterm_frag:
        return _calc_modloss(mod_losses)[1:-2]
    else:
        return _calc_modloss(mod_losses[::-1])[-3:0:-1]

# %%
#hide
mod_names = ['Oxidation@M', 'Phospho@S', 'Carbamidomethyl@C']
mod_sites = [0, 4, 8]

assert np.allclose(
    calc_modloss_mass(10, mod_names, mod_sites, True),
    [63.99828592, 63.99828592, 63.99828592, 97.97689557, 97.97689557,
       97.97689557, 97.97689557, 97.97689557, 97.97689557]
)

# %%
#hide
assert np.allclose(
    calc_modloss_mass(10, mod_names, mod_sites, False),
    [97.97689557, 97.97689557, 97.97689557,  0 ,  0,
        0,  0 ,  0,  0]
)

# %% [markdown]
# ### Note that get_modloss_mass is a little bit time comsuming
# `%timeit get_modloss_mass(10, mod_names, mod_sites, False)`
#
# `Results (12 seconds in total): 12.6 µs ± 96.4 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)`

# %%
MOD_DF.drop_duplicates('classification')
# Out:
#                                    avge_mass            classification  \
# GlyGly@K                          114.042927        Post-translational
# 15N-oxobutanoic@C^Any N-term      -18.023900                  Artefact
# 2-dimethylsuccinyl@C              144.125300       Chemical derivative
# 3-deoxyglucosone@R                144.125300                  Multiple
# ADP-Ribosyl@C                     541.300500       Other glycosylation
# ADP-Ribosyl@N                     541.300500    N-linked glycosylation
# ADP-Ribosyl@S                     541.300500    O-linked glycosylation
# AEC-MAEC:2H(4)@S                   63.158000            Isotopic label
# Ahx2+Hsl@Any C-term               309.403900      Non-standard residue
# Ala->Arg@A                         85.107800           AA substitution
# Arg-loss@R^Any C-term            -156.185700                     Other
# FormylMet@Protein N-term          159.206200         Pre-translational
# HexN@K                            161.155800  Synth. pep. protect. gp.
# Met-loss+Acetyl@M^Protein N-term  -89.159400          Co-translational
#
#                                                  composition     modloss  \
# GlyGly@K                                    H(6)C(4)N(2)O(2)  114.042927
# 15N-oxobutanoic@C^Any N-term                    H(-3)15N(-1)    0.000000
# 2-dimethylsuccinyl@C                            H(8)C(6)O(4)    0.000000
# 3-deoxyglucosone@R                              H(8)C(6)O(4)    0.000000
# ADP-Ribosyl@C                        H(21)C(15)N(5)O(13)P(2)    0.000000
# ADP-Ribosyl@N                        H(21)C(15)N(5)O(13)P(2)  541.061110
# ADP-Ribosyl@S                        H(21)C(15)N(5)O(13)P(2)  541.061110
# AEC-MAEC:2H(4)@S                  H(1)2H(4)C(2)N(1)O(-1)S(1)    0.000000
# Ahx2+Hsl@Any C-term                       H(27)C(16)N(3)O(3)    0.000000
# Ala->Arg@A                              H(7)C(3)N(3)O(0)S(0)    0.000000
# Arg-loss@R^Any C-term                  H(-12)C(-6)N(-4)O(-1)    0.000000
# FormylMet@Protein N-term                H(9)C(6)N(1)O(2)S(1)    0.000000
# HexN@K                                     H(11)C(6)N(1)O(4)    0.000000
# Met-loss+Acetyl@M^Protein N-term        H(-7)C(-3)N(-1)S(-1)    0.000000
#
#                                       modloss_composition   mono_mass  \
# GlyGly@K                                 H(6)C(4)N(2)O(2)  114.042927
# 15N-oxobutanoic@C^Any N-term                               -18.023584
# 2-dimethylsuccinyl@C                                       144.042259
# 3-deoxyglucosone@R                                         144.042259
# ADP-Ribosyl@C                                              541.061110
# ADP-Ribosyl@N                     H(21)C(15)N(5)O(13)P(2)  541.061110
# ADP-Ribosyl@S                     H(21)C(15)N(5)O(13)P(2)  541.061110
# AEC-MAEC:2H(4)@S                                            63.044462
# Ahx2+Hsl@Any C-term                                        309.205242
# Ala->Arg@A                                                  85.063997
# Arg-loss@R^Any C-term                                     -156.101111
# FormylMet@Protein N-term                                   159.035399
# HexN@K                                                     161.068808
# Met-loss+Acetyl@M^Protein N-term                           -89.029920
#
#                                   unimod_id  unimod_mass  unimod_modloss  \
# GlyGly@K                                 -1   114.042927      114.042927
# 15N-oxobutanoic@C^Any N-term           1419   -18.023584        0.000000
# 2-dimethylsuccinyl@C                   1262   144.042259        0.000000
# 3-deoxyglucosone@R                      949   144.042259        0.000000
# ADP-Ribosyl@C                           213   541.061110        0.000000
# ADP-Ribosyl@N                           213   541.061110      541.061110
# ADP-Ribosyl@S                           213   541.061110      541.061110
# AEC-MAEC:2H(4)@S                        792    63.044462        0.000000
# Ahx2+Hsl@Any C-term                    1015   309.205242        0.000000
# Ala->Arg@A                             1052    85.063997        0.000000
# Arg-loss@R^Any C-term                  1287  -156.101111        0.000000
# FormylMet@Protein N-term                107   159.035399        0.000000
# HexN@K                                  454   161.068808        0.000000
# Met-loss+Acetyl@M^Protein N-term        766   -89.029920        0.000000
#
#                                         mass modloss_importance  \
# GlyGly@K                          114.042927                1e6
# 15N-oxobutanoic@C^Any N-term      -18.023584                  0
# 2-dimethylsuccinyl@C              144.042259                  0
# 3-deoxyglucosone@R                144.042259                  0
# ADP-Ribosyl@C                     541.061110                  0
# ADP-Ribosyl@N                     541.061110                  0
# ADP-Ribosyl@S                     541.061110                  0
# AEC-MAEC:2H(4)@S                   63.044463                  0
# Ahx2+Hsl@Any C-term               309.205242                  0
# Ala->Arg@A                         85.063997                  0
# Arg-loss@R^Any C-term            -156.101111                  0
# FormylMet@Protein N-term          159.035400                  0
# HexN@K                            161.068808                  0
# Met-loss+Acetyl@M^Protein N-term  -89.029920                  0
#
#                                                               name
# GlyGly@K                                                  GlyGly@K
# 15N-oxobutanoic@C^Any N-term          15N-oxobutanoic@C^Any N-term
# 2-dimethylsuccinyl@C                          2-dimethylsuccinyl@C
# 3-deoxyglucosone@R                              3-deoxyglucosone@R
# ADP-Ribosyl@C                                        ADP-Ribosyl@C
# ADP-Ribosyl@N                                        ADP-Ribosyl@N
# ADP-Ribosyl@S                                        ADP-Ribosyl@S
# AEC-MAEC:2H(4)@S                                  AEC-MAEC:2H(4)@S
# Ahx2+Hsl@Any C-term                            Ahx2+Hsl@Any C-term
# Ala->Arg@A                                              Ala->Arg@A
# Arg-loss@R^Any C-term                        Arg-loss@R^Any C-term
# FormylMet@Protein N-term                  FormylMet@Protein N-term
# HexN@K                                                      HexN@K
# Met-loss+Acetyl@M^Protein N-term  Met-loss+Acetyl@M^Protein N-term

# %% [markdown]
# ## We can update modification list for differet requirements, for example:

# %%
add_modifications_for_lower_case_AA()
MOD_DF = MOD_DF[
    (MOD_DF['classification'].isin(['Post-translational','O-linked glycosylation','AA substitution','Multiple','Non-standard residue','Pre-translational']))
    & MOD_DF['lower_case_AA']
] # we only need PTMs
update_all_by_MOD_DF()
# MOD_INFO_DICT is also updated
pd.DataFrame().from_dict(MOD_INFO_DICT, orient='index')
# Out:
#                                    avge_mass          classification  \
# GlyGly@k                          114.042927      Post-translational
# 15N-oxobutanoic@s^Protein N-term  -18.023900      Post-translational
# 15N-oxobutanoic@t^Protein N-term  -18.023900      Post-translational
# 3-deoxyglucosone@r                144.125300                Multiple
# 3-phosphoglyceryl@k               168.042000      Post-translational
# ...                                      ...                     ...
# pyrophospho@t                     159.959800      Post-translational
# s-GlcNAc@s                        283.255700  O-linked glycosylation
# s-GlcNAc@t                        283.255700  O-linked glycosylation
# serotonylation@q                  159.184600      Post-translational
# trifluoro@l                        53.971400    Non-standard residue
#
#                                             composition     modloss  \
# GlyGly@k                               H(6)C(4)N(2)O(2)  114.042927
# 15N-oxobutanoic@s^Protein N-term           H(-3)15N(-1)    0.000000
# 15N-oxobutanoic@t^Protein N-term           H(-3)15N(-1)    0.000000
# 3-deoxyglucosone@r                         H(8)C(6)O(4)    0.000000
# 3-phosphoglyceryl@k                    H(5)C(3)O(6)P(1)    0.000000
# ...                                                 ...         ...
# pyrophospho@t                              H(2)O(6)P(2)  176.935401
# s-GlcNAc@s                        H(13)C(8)N(1)O(8)S(1)  283.036188
# s-GlcNAc@t                        H(13)C(8)N(1)O(8)S(1)  283.036188
# serotonylation@q                      H(9)C(10)N(1)O(1)    0.000000
# trifluoro@l                                   H(-3)F(3)    0.000000
#
#                                     modloss_composition   mono_mass  \
# GlyGly@k                               H(6)C(4)N(2)O(2)  114.042927
# 15N-oxobutanoic@s^Protein N-term                         -18.023584
# 15N-oxobutanoic@t^Protein N-term                         -18.023584
# 3-deoxyglucosone@r                                       144.042259
# 3-phosphoglyceryl@k                                      167.982375
# ...                                                 ...         ...
# pyrophospho@t                              H(3)O(7)P(2)  159.932662
# s-GlcNAc@s                        H(13)C(8)N(1)O(8)S(1)  283.036187
# s-GlcNAc@t                        H(13)C(8)N(1)O(8)S(1)  283.036187
# serotonylation@q                                         159.068414
# trifluoro@l                                               53.971735
#
#                                   unimod_id  unimod_mass  unimod_modloss  \
# GlyGly@k                                 -1   114.042927      114.042927
# 15N-oxobutanoic@s^Protein N-term       1419   -18.023584        0.000000
# 15N-oxobutanoic@t^Protein N-term       1419   -18.023584        0.000000
# 3-deoxyglucosone@r                      949   144.042259        0.000000
# 3-phosphoglyceryl@k                    1387   167.982375        0.000000
# ...                                     ...          ...             ...
# pyrophospho@t                           898   159.932662      176.935402
# s-GlcNAc@s                             1412   283.036187      283.036187
# s-GlcNAc@t                             1412   283.036187      283.036187
# serotonylation@q                       1992   159.068414        0.000000
# trifluoro@l                             750    53.971735        0.000000
#
#                                         mass modloss_importance  \
# GlyGly@k                          114.042927                1e6
# 15N-oxobutanoic@s^Protein N-term  -18.023584                  0
# 15N-oxobutanoic@t^Protein N-term  -18.023584                  0
# 3-deoxyglucosone@r                144.042259                  0
# 3-phosphoglyceryl@k               167.982375                  0
# ...                                      ...                ...
# pyrophospho@t                     159.932662                  0
# s-GlcNAc@s                        283.036188                  0
# s-GlcNAc@t                        283.036188                  0
# serotonylation@q                  159.068414                  0
# trifluoro@l                        53.971734                  0
#
#                                                               name  \
# GlyGly@k                                                  GlyGly@k
# 15N-oxobutanoic@s^Protein N-term  15N-oxobutanoic@s^Protein N-term
# 15N-oxobutanoic@t^Protein N-term  15N-oxobutanoic@t^Protein N-term
# 3-deoxyglucosone@r                              3-deoxyglucosone@r
# 3-phosphoglyceryl@k                            3-phosphoglyceryl@k
# ...                                                            ...
# pyrophospho@t                                        pyrophospho@t
# s-GlcNAc@s                                              s-GlcNAc@s
# s-GlcNAc@t                                              s-GlcNAc@t
# serotonylation@q                                  serotonylation@q
# trifluoro@l                                            trifluoro@l
#
#                                   lower_case_AA
# GlyGly@k                                   True
# 15N-oxobutanoic@s^Protein N-term           True
# 15N-oxobutanoic@t^Protein N-term           True
# 3-deoxyglucosone@r                         True
# 3-phosphoglyceryl@k                        True
# ...                                         ...
# pyrophospho@t                              True
# s-GlcNAc@s                                 True
# s-GlcNAc@t                                 True
# serotonylation@q                           True
# trifluoro@l                                True
#
# [1249 rows x 13 columns]

# %%
#hide
load_mod_yaml(
    os.path.join(_base_dir,
    'used_mod.yaml')
)
add_modifications_for_lower_case_AA()
MOD_DF = MOD_DF[
    MOD_DF['lower_case_AA']
] # we only need PTMs
assert MOD_DF['name'].apply(lambda x: x[x.find('@')+1].islower()).all()
