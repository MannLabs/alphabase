# %% [markdown]
# # Tutorial for Dev: Peptide and Fragment DataFrames
#
# This notebook introduces functionalities for peptide and fragment DataFrames to developers.

# %% [markdown]
# ## Peptide DataFrame
#
# Peptide dataframe must contain four columns: `sequence` for animo acid sequence (str), `mods` for modification names (str), `mod_sites` for modification sites (str), and `charge` for precursor charge states (int).
#
# We can easily build a peptide dataframe:

# %%
import pandas as pd

df = pd.DataFrame({
    'sequence': ['ACDEFHIK', 'APDEFMNIK', 'SWDEFMNTIRAAAAKDDDDR'],
    'mods': ['Carbamidomethyl@C', '', 'Phospho@S;Oxidation@M'],
    'mod_sites': ['2', '', '1;6'],
    'charge': [1,2,3],
})
df
# Out:
#                sequence                   mods mod_sites  charge
# 0              ACDEFHIK      Carbamidomethyl@C         2       1
# 1             APDEFMNIK                                        2
# 2  SWDEFMNTIRAAAAKDDDDR  Phospho@S;Oxidation@M       1;6       3

# %% [markdown]
# ### Calculate precursor_mz and isotopes from peptide dataframe

# %% [markdown]
# `alphabase.peptide.precursor.update_precursor_mz()` calculates the precursor_mz for peptides.

# %%
from alphabase.peptide.precursor import update_precursor_mz

update_precursor_mz(df)
# Out:
#                sequence                   mods mod_sites  charge  nAA  \
# 0              ACDEFHIK      Carbamidomethyl@C         2       1    8
# 1             APDEFMNIK                                        2    9
# 2  SWDEFMNTIRAAAAKDDDDR  Phospho@S;Oxidation@M       1;6       3   20
#
#    precursor_mz
# 0   1019.461492
# 1    532.757692
# 2    808.337166

# %% [markdown]
# `alphabase.peptide.precursor.calc_precursor_isotope()` calculates the precursor isotope information for peptides. It will add `isotope_*` columns for peptides.
#
# - isotope_m1_intensity: relative intensity of M1 to mono peak
# - isotope_m1_mz: mz of M1
# - isotope_apex_intensity: relative intensity of the apex peak
# - isotope_apex_mz: mz of the apex peak
# - isotope_apex_offset: position offset of the apex peak to mono peak
# - isotope_right_most_intensity: relative intensity of the right-most peak
# - isotope_right_most_mz: mz of the right-most peak
# - isotope_right_most_offset: position offset of the right-most peak

# %%
from alphabase.peptide.precursor import calc_precursor_isotope

calc_precursor_isotope(df)
# Out:
#                sequence                   mods mod_sites  charge  nAA  \
# 0              ACDEFHIK      Carbamidomethyl@C         2       1    8
# 1             APDEFMNIK                                        2    9
# 2  SWDEFMNTIRAAAAKDDDDR  Phospho@S;Oxidation@M       1;6       3   20
#
#    precursor_mz  isotope_m1_intensity  isotope_apex_intensity  \
# 0   1019.461492              0.539940                1.000000
# 1    532.757692              0.569920                1.000000
# 2    808.337166              1.194615                1.194615
#
#    isotope_apex_offset  isotope_right_most_intensity  \
# 0                    0                      0.214538
# 1                    0                      0.233061
# 2                    1                      0.425938
#
#    isotope_right_most_offset  isotope_m1_mz  isotope_apex_mz  \
# 0                          2    1020.464792      1019.461492
# 1                          2     533.259342       532.757692
# 2                          3     808.671599       808.671599
#
#    isotope_right_most_mz
# 0            1021.468092
# 1             533.760992
# 2             809.340466

# %% [markdown]
# > Computing isotope patterns is very time-consuming for millions of peptides, so we provided `calc_precursor_isotope_mp` with multiprocessing for users.

# %% [markdown]
# ## Fragment DataFrame
#
# `alphabase.peptide.fragment.create_fragment_mz_dataframe()` is the only function we need to calculate fragment_mz dataframe. It has two key parameters:
#
# - precursor_df (pd.DataFrame): the peptide or precursor dataframe.
# - charged_frag_types (list of str): The charged fragments to be considered into the fragment dataframe columns. The schema is `Type[_LossType]_z[n]`, where
#   - `Type` can be `b,y,c,z`
#   - `_LossType` can be `_modloss,_H2O,_NH3`, this is optional.
#   - `z[n]` is the charge state. If precursor charge is less than `n`, the corresponding mz will be set as zero.

# %%
from alphabase.peptide.fragment import create_fragment_mz_dataframe
frag_mz_df = create_fragment_mz_dataframe(
    df,
    charged_frag_types=['a_z1','b_z1','c_z1','b_z2','x_z1','y_z1', 'y_H2O_z1','z_z1']
)
frag_mz_df
# Out:
#            a_z1         b_z1         c_z1         b_z2         x_z1  \
# 0     44.049476    72.044390    89.070939     0.000000   974.403643
# 1    204.080124   232.075039   249.101588     0.000000   814.372995
# 2    319.107067   347.101982   364.128531     0.000000   699.346052
# 3    448.149660   476.144575   493.171124     0.000000   570.303458
# 4    595.218074   623.212989   640.239538     0.000000   423.235045
# 5    732.276986   760.271901   777.298450     0.000000   286.176133
# 6    845.361050   873.355965   890.382514     0.000000   173.092069
# 7     44.049476    72.044390    89.070939    36.525833  1019.450259
# 8    141.102239   169.097154   186.123703    85.052215   922.397495
# 9    256.129183   284.124097   301.150646   142.565687   807.370552
# 10   385.171776   413.166690   430.193239   207.086983   678.327959
# 11   532.240190   560.235104   577.261653   280.621190   531.259545
# 12   663.280675   691.275589   708.302138   346.141433   400.219060
# 13   777.323602   805.318517   822.345066   403.162897   286.176133
# 14   890.407666   918.402581   935.429130   459.704929   173.092069
# 15   140.010721   168.005636   185.032185    84.506456  2281.977851
# 16   326.090034   354.084949   371.111498   177.546113  2095.898538
# 17   441.116977   469.111892   486.138441   235.059584  1980.871595
# 18   570.159570   598.154485   615.181034   299.580881  1851.829002
# 19   717.227984   745.222899   762.249448   373.115088  1704.760588
# 20   864.263384   892.258298   909.284848   446.632787  1557.725188
# 21   978.306311  1006.301226  1023.327775   503.654251  1443.682260
# 22  1079.353990  1107.348904  1124.375453   554.178090  1342.634582
# 23  1192.438054  1220.432968  1237.459517   610.720122  1229.550518
# 24  1348.539165  1376.534079  1393.560628   688.770678  1073.449407
# 25  1419.576279  1447.571193  1464.597742   724.289235  1002.412293
# 26  1490.613392  1518.608307  1535.634856   759.807792   931.375179
# 27  1561.650506  1589.645421  1606.671970   795.326349   860.338066
# 28  1632.687620  1660.682535  1677.709084   830.844905   789.300952
# 29  1760.782583  1788.777498  1805.804047   894.892387   661.205989
# 30  1875.809526  1903.804441  1920.830990   952.405859   546.179046
# 31  1990.836469  2018.831384  2035.857933  1009.919330   431.152103
# 32  2105.863412  2133.858327  2150.884876  1067.432802   316.125160
# 33  2220.890355  2248.885270  2265.911819  1124.946273   201.098217
#
#            y_z1     y_H2O_z1         z_z1
# 0    948.424379   930.413814   932.405655
# 1    788.393730   770.383165   772.375006
# 2    673.366787   655.356222   657.348063
# 3    544.324194   526.313629   528.305470
# 4    397.255780   379.245215   381.237056
# 5    260.196868   242.186303   244.178144
# 6    147.112804   129.102239   131.094080
# 7    993.470995   975.460430   977.452270
# 8    896.418231   878.407666   880.399507
# 9    781.391288   763.380723   765.372564
# 10   652.348695   634.338130   636.329971
# 11   505.280281   487.269716   489.261557
# 12   374.239796   356.229231   358.221072
# 13   260.196868   242.186303   244.178144
# 14   147.112804   129.102239   131.094080
# 15  2255.998586  2237.988021  2239.979862
# 16  2069.919273  2051.908708  2053.900549
# 17  1954.892330  1936.881765  1938.873606
# 18  1825.849737  1807.839172  1809.831013
# 19  1678.781323  1660.770758  1662.762599
# 20  1531.745923  1513.735359  1515.727199
# 21  1417.702996  1399.692431  1401.684272
# 22  1316.655317  1298.644753  1300.636593
# 23  1203.571253  1185.560689  1187.552529
# 24  1047.470142  1029.459578  1031.451418
# 25   976.433029   958.422464   960.414305
# 26   905.395915   887.385350   889.377191
# 27   834.358801   816.348236   818.340077
# 28   763.321687   745.311123   747.302963
# 29   635.226724   617.216160   619.208000
# 30   520.199781   502.189217   504.181057
# 31   405.172838   387.162274   389.154114
# 32   290.145895   272.135331   274.127171
# 33   175.118952   157.108387   159.100228

# %% [markdown]
# After `create_fragment_mz_dataframe()`, two columns `frag_start_idx` and `frag_stop_idx` will be append to the peptide dataframe. These two values locate the fragment in the fragment dataframe of a peptide.

# %%
df[[
    'sequence','mods','mod_sites','charge','nAA',
    'precursor_mz','frag_start_idx','frag_stop_idx'
]]
# Out:
#                sequence                   mods mod_sites  charge  nAA  \
# 0              ACDEFHIK      Carbamidomethyl@C         2       1    8
# 1             APDEFMNIK                                        2    9
# 2  SWDEFMNTIRAAAAKDDDDR  Phospho@S;Oxidation@M       1;6       3   20
#
#    precursor_mz  frag_start_idx  frag_stop_idx
# 0   1019.461492               0              7
# 1    532.757692               7             15
# 2    808.337166              15             34

# %%
start,stop = df[['frag_start_idx','frag_stop_idx']].values[0] #first peptide
frag_mz_df.iloc[start:stop]
# Out:
#          a_z1        b_z1        c_z1  b_z2        x_z1        y_z1  \
# 0   44.049476   72.044390   89.070939   0.0  974.403643  948.424379
# 1  204.080124  232.075039  249.101588   0.0  814.372995  788.393730
# 2  319.107067  347.101982  364.128531   0.0  699.346052  673.366787
# 3  448.149660  476.144575  493.171124   0.0  570.303458  544.324194
# 4  595.218074  623.212989  640.239538   0.0  423.235045  397.255780
# 5  732.276986  760.271901  777.298450   0.0  286.176133  260.196868
# 6  845.361050  873.355965  890.382514   0.0  173.092069  147.112804
#
#      y_H2O_z1        z_z1
# 0  930.413814  932.405655
# 1  770.383165  772.375006
# 2  655.356222  657.348063
# 3  526.313629  528.305470
# 4  379.245215  381.237056
# 5  242.186303  244.178144
# 6  129.102239  131.094080

# %% [markdown]
# Note that all N-term (a/b/c) fragment mz values are in ascending order, e.g. from b[1] to b[n-1]; and all C-term (x/y/z) fragments are in descending order, e.g. from y[n-1] to y[1].

# %% [markdown]
# All dataframe functionalities use low-level APIs of AlphaBase, see `tutorial_dev_basic_definations.ipynb` or `Tutorial for Dev: Basic Definations`.
#
# Spectral library functionalities provide higher-level APIs which encapsulate these dataframe functionalities, see `tutorial_dev_spectral_libraries.ipynb` or `Tutorial for Dev: Spectral Libraries`.
